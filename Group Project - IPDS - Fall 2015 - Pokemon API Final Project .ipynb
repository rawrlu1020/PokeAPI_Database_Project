# %% [markdown]
# # Part 1: Scraping PokeApi for Data

# %%
import requests
import json

# %%
#We look to see how the information from the Pokeapi is stored
url = 'http://pokeapi.co/api/v1/pokedex'
resp = requests.get(url)
data = json.loads(resp.text)
data
# Out:
# {u'meta': {u'limit': 1,
#   u'next': None,
#   u'offset': 0,
#   u'previous': None,
#   u'total_count': 1},
#  u'objects': [{u'created': u'2013-11-09T15:14:48.957604',
#    u'modified': u'2013-11-09T15:14:48.957565',
#    u'name': u'national',
#    u'pokemon': [{u'name': u'rattata', u'resource_uri': u'api/v1/pokemon/19/'},
#     {u'name': u'charmander', u'resource_uri': u'api/v1/pokemon/4/'},
#     {u'name': u'charmeleon', u'resource_uri': u'api/v1/pokemon/5/'},
#     {u'name': u'wartortle', u'resource_uri': u'api/v1/pokemon/8/'},
#     {u'name': u'blastoise', u'resource_uri': u'api/v1/pokemon/9/'},
#     {u'name': u'caterpie', u'resource_uri': u'api/v1/pokemon/10/'},
#     {u'name': u'metapod', u'resource_uri': u'api/v1/pokemon/11/'},
#     {u'name': u'butterfree', u'resource_uri': u'api/v1/pokemon/12/'},
#     {u'name': u'spearow', u'resource_uri': u'api/v1/pokemon/21/'},
#     {u'name': u'kakuna', u'resource_uri': u'api/v1/pokemon/14/'},
#     {u'name': u'beedrill', u'resource_uri': u'api/v1/pokemon/15/'},
#     {u'name': u'pidgey', u'resource_uri': u'api/v1/pokemon/16/'},
#     {u'name': u'pidgeotto', u'resource_uri': u'api/v1/pokemon/17/'},
#     {u'name': u'pidgeot', u'resource_uri': u'api/v1/pokemon/18/'},
#     {u'name': u'raticate', u'resource_uri': u'api/v1/pokemon/20/'},
#     {u'name': u'fearow', u'resource_uri': u'api/v1/pokemon/22/'},
#     {u'name': u'pikachu', u'resource_uri': u'api/v1/pokemon/25/'},
#     {u'name': u'ekans', u'resource_uri': u'api/v1/pokemon/23/'},
#     {u'name': u'raichu', u'resource_uri': u'api/v1/pokemon/26/'},
#     {u'name': u'arbok', u'resource_uri': u'api/v1/pokemon/24/'},
#     {u'name': u'nidorina', u'resource_uri': u'api/v1/pokemon/30/'},
#     {u'name': u'sandshrew', u'resource_uri': u'api/v1/pokemon/27/'},
#     {u'name': u'nidoran-m', u'resource_uri': u'api/v1/pokemon/32/'},
#     {u'name': u'nidoran-f', u'resource_uri': u'api/v1/pokemon/29/'},
#     {u'name': u'nidoqueen', u'resource_uri': u'api/v1/pokemon/31/'},
#     {u'name': u'nidorino', u'resource_uri': u'api/v1/pokemon/33/'},
#     {u'name': u'nidoking', u'resource_uri': u'api/v1/pokemon/34/'},
#     {u'name': u'clefable', u'resource_uri': u'api/v1/pokemon/36/'},
#     {u'name': u'jigglypuff', u'resource_uri': u'api/v1/pokemon/39/'},
#     {u'name': u'vulpix', u'resource_uri': u'api/v1/pokemon/37/'},
#     {u'name': u'ninetales', u'resource_uri': u'api/v1/pokemon/38/'},
#     {u'name': u'wigglytuff', u'resource_uri': u'api/v1/pokemon/40/'},
#     {u'name': u'zubat', u'resource_uri': u'api/v1/pokemon/41/'},
#     {u'name': u'venonat', u'resource_uri': u'api/v1/pokemon/48/'},
#     {u'name': u'meowth', u'resource_uri': u'api/v1/pokemon/52/'},
#     {u'name': u'golbat', u'resource_uri': u'api/v1/pokemon/42/'},
#     {u'name': u'oddish', u'resource_uri': u'api/v1/pokemon/43/'},
#     {u'name': u'gloom', u'resource_uri': u'api/v1/pokemon/44/'},
#     {u'name': u'vileplume', u'resource_uri': u'api/v1/pokemon/45/'},
#     {u'name': u'paras', u'resource_uri': u'api/v1/pokemon/46/'},
#     {u'name': u'parasect', u'resource_uri': u'api/v1/pokemon/47/'},
#     {u'name': u'venomoth', u'resource_uri': u'api/v1/pokemon/49/'},
#     {u'name': u'diglett', u'resource_uri': u'api/v1/pokemon/50/'},
#     {u'name': u'dugtrio', u'resource_uri': u'api/v1/pokemon/51/'},
#     {u'name': u'persian', u'resource_uri': u'api/v1/pokemon/53/'},
#     {u'name': u'psyduck', u'resource_uri': u'api/v1/pokemon/54/'},
#     {u'name': u'golduck', u'resource_uri': u'api/v1/pokemon/55/'},
#     {u'name': u'mankey', u'resource_uri': u'api/v1/pokemon/56/'},
#     {u'name': u'growlithe', u'resource_uri': u'api/v1/pokemon/58/'},
#     {u'name': u'arcanine', u'resource_uri': u'api/v1/pokemon/59/'},
#     {u'name': u'poliwag', u'resource_uri': u'api/v1/pokemon/60/'},
#     {u'name': u'poliwhirl', u'resource_uri': u'api/v1/pokemon/61/'},
#     {u'name': u'poliwrath', u'resource_uri': u'api/v1/pokemon/62/'},
#     {u'name': u'abra', u'resource_uri': u'api/v1/pokemon/63/'},
#     {u'name': u'kadabra', u'resource_uri': u'api/v1/pokemon/64/'},
#     {u'name': u'machop', u'resource_uri': u'api/v1/pokemon/66/'},
#     {u'name': u'machoke', u'resource_uri': u'api/v1/pokemon/67/'},
#     {u'name': u'machamp', u'resource_uri': u'api/v1/pokemon/68/'},
#     {u'name': u'bellsprout', u'resource_uri': u'api/v1/pokemon/69/'},
#     {u'name': u'ivysaur', u'resource_uri': u'api/v1/pokemon/2/'},
#     {u'name': u'venusaur', u'resource_uri': u'api/v1/pokemon/3/'},
#     {u'name': u'squirtle', u'resource_uri': u'api/v1/pokemon/7/'},
#     {u'name': u'weedle', u'resource_uri': u'api/v1/pokemon/13/'},
#     {u'name': u'graveler', u'resource_uri': u'api/v1/pokemon/75/'},
#     {u'name': u'geodude', u'resource_uri': u'api/v1/pokemon/74/'},
#     {u'name': u'golem', u'resource_uri': u'api/v1/pokemon/76/'},
#     {u'name': u'ponyta', u'resource_uri': u'api/v1/pokemon/77/'},
#     {u'name': u'rapidash', u'resource_uri': u'api/v1/pokemon/78/'},
#     {u'name': u'slowbro', u'resource_uri': u'api/v1/pokemon/80/'},
#     {u'name': u'grimer', u'resource_uri': u'api/v1/pokemon/88/'},
#     {u'name': u'farfetchd', u'resource_uri': u'api/v1/pokemon/83/'},
#     {u'name': u'magnemite', u'resource_uri': u'api/v1/pokemon/81/'},
#     {u'name': u'magneton', u'resource_uri': u'api/v1/pokemon/82/'},
#     {u'name': u'doduo', u'resource_uri': u'api/v1/pokemon/84/'},
#     {u'name': u'seel', u'resource_uri': u'api/v1/pokemon/86/'},
#     {u'name': u'dodrio', u'resource_uri': u'api/v1/pokemon/85/'},
#     {u'name': u'dewgong', u'resource_uri': u'api/v1/pokemon/87/'},
#     {u'name': u'gastly', u'resource_uri': u'api/v1/pokemon/92/'},
#     {u'name': u'cloyster', u'resource_uri': u'api/v1/pokemon/91/'},
#     {u'name': u'muk', u'resource_uri': u'api/v1/pokemon/89/'},
#     {u'name': u'krabby', u'resource_uri': u'api/v1/pokemon/98/'},
#     {u'name': u'haunter', u'resource_uri': u'api/v1/pokemon/93/'},
#     {u'name': u'gengar', u'resource_uri': u'api/v1/pokemon/94/'},
#     {u'name': u'onix', u'resource_uri': u'api/v1/pokemon/95/'},
#     {u'name': u'drowzee', u'resource_uri': u'api/v1/pokemon/96/'},
#     {u'name': u'hypno', u'resource_uri': u'api/v1/pokemon/97/'},
#     {u'name': u'kingler', u'resource_uri': u'api/v1/pokemon/99/'},
#     {u'name': u'voltorb', u'resource_uri': u'api/v1/pokemon/100/'},
#     {u'name': u'electrode', u'resource_uri': u'api/v1/pokemon/101/'},
#     {u'name': u'exeggcute', u'resource_uri': u'api/v1/pokemon/102/'},
#     {u'name': u'exeggutor', u'resource_uri': u'api/v1/pokemon/103/'},
#     {u'name': u'hitmonlee', u'resource_uri': u'api/v1/pokemon/106/'},
#     {u'name': u'cubone', u'resource_uri': u'api/v1/pokemon/104/'},
#     {u'name': u'lickitung', u'resource_uri': u'api/v1/pokemon/108/'},
#     {u'name': u'hitmonchan', u'resource_uri': u'api/v1/pokemon/107/'},
#     {u'name': u'koffing', u'resource_uri': u'api/v1/pokemon/109/'},
#     {u'name': u'weezing', u'resource_uri': u'api/v1/pokemon/110/'},
#     {u'name': u'rhyhorn', u'resource_uri': u'api/v1/pokemon/111/'},
#     {u'name': u'rhydon', u'resource_uri': u'api/v1/pokemon/112/'},
#     {u'name': u'chansey', u'resource_uri': u'api/v1/pokemon/113/'},
#     {u'name': u'kangaskhan', u'resource_uri': u'api/v1/pokemon/115/'},
#     {u'name': u'horsea', u'resource_uri': u'api/v1/pokemon/116/'},
#     {u'name': u'tangela', u'resource_uri': u'api/v1/pokemon/114/'},
#     {u'name': u'seadra', u'resource_uri': u'api/v1/pokemon/117/'},
#     {u'name': u'goldeen', u'resource_uri': u'api/v1/pokemon/118/'},
#     {u'name': u'staryu', u'resource_uri': u'api/v1/pokemon/120/'},
#     {u'name': u'mr-mime', u'resource_uri': u'api/v1/pokemon/122/'},
#     {u'name': u'starmie', u'resource_uri': u'api/v1/pokemon/121/'},
#     {u'name': u'scyther', u'resource_uri': u'api/v1/pokemon/123/'},
#     {u'name': u'pinsir', u'resource_uri': u'api/v1/pokemon/127/'},
#     {u'name': u'jynx', u'resource_uri': u'api/v1/pokemon/124/'},
#     {u'name': u'electabuzz', u'resource_uri': u'api/v1/pokemon/125/'},
#     {u'name': u'magmar', u'resource_uri': u'api/v1/pokemon/126/'},
#     {u'name': u'tauros', u'resource_uri': u'api/v1/pokemon/128/'},
#     {u'name': u'gyarados', u'resource_uri': u'api/v1/pokemon/130/'},
#     {u'name': u'lapras', u'resource_uri': u'api/v1/pokemon/131/'},
#     {u'name': u'ditto', u'resource_uri': u'api/v1/pokemon/132/'},
#     {u'name': u'eevee', u'resource_uri': u'api/v1/pokemon/133/'},
#     {u'name': u'jolteon', u'resource_uri': u'api/v1/pokemon/135/'},
#     {u'name': u'vaporeon', u'resource_uri': u'api/v1/pokemon/134/'},
#     {u'name': u'flareon', u'resource_uri': u'api/v1/pokemon/136/'},
#     {u'name': u'porygon', u'resource_uri': u'api/v1/pokemon/137/'},
#     {u'name': u'omanyte', u'resource_uri': u'api/v1/pokemon/138/'},
#     {u'name': u'victreebel', u'resource_uri': u'api/v1/pokemon/71/'},
#     {u'name': u'tentacool', u'resource_uri': u'api/v1/pokemon/72/'},
#     {u'name': u'tentacruel', u'resource_uri': u'api/v1/pokemon/73/'},
#     {u'name': u'snorlax', u'resource_uri': u'api/v1/pokemon/143/'},
#     {u'name': u'articuno', u'resource_uri': u'api/v1/pokemon/144/'},
#     {u'name': u'mewtwo', u'resource_uri': u'api/v1/pokemon/150/'},
#     {u'name': u'moltres', u'resource_uri': u'api/v1/pokemon/146/'},
#     {u'name': u'totodile', u'resource_uri': u'api/v1/pokemon/158/'},
#     {u'name': u'dratini', u'resource_uri': u'api/v1/pokemon/147/'},
#     {u'name': u'dragonair', u'resource_uri': u'api/v1/pokemon/148/'},
#     {u'name': u'bayleef', u'resource_uri': u'api/v1/pokemon/153/'},
#     {u'name': u'mew', u'resource_uri': u'api/v1/pokemon/151/'},
#     {u'name': u'chikorita', u'resource_uri': u'api/v1/pokemon/152/'},
#     {u'name': u'meganium', u'resource_uri': u'api/v1/pokemon/154/'},
#     {u'name': u'igglybuff', u'resource_uri': u'api/v1/pokemon/174/'},
#     {u'name': u'cyndaquil', u'resource_uri': u'api/v1/pokemon/155/'},
#     {u'name': u'quilava', u'resource_uri': u'api/v1/pokemon/156/'},
#     {u'name': u'typhlosion', u'resource_uri': u'api/v1/pokemon/157/'},
#     {u'name': u'croconaw', u'resource_uri': u'api/v1/pokemon/159/'},
#     {u'name': u'feraligatr', u'resource_uri': u'api/v1/pokemon/160/'},
#     {u'name': u'noctowl', u'resource_uri': u'api/v1/pokemon/164/'},
#     {u'name': u'sentret', u'resource_uri': u'api/v1/pokemon/161/'},
#     {u'name': u'furret', u'resource_uri': u'api/v1/pokemon/162/'},
#     {u'name': u'hoothoot', u'resource_uri': u'api/v1/pokemon/163/'},
#     {u'name': u'ledyba', u'resource_uri': u'api/v1/pokemon/165/'},
#     {u'name': u'ledian', u'resource_uri': u'api/v1/pokemon/166/'},
#     {u'name': u'ariados', u'resource_uri': u'api/v1/pokemon/168/'},
#     {u'name': u'crobat', u'resource_uri': u'api/v1/pokemon/169/'},
#     {u'name': u'chinchou', u'resource_uri': u'api/v1/pokemon/170/'},
#     {u'name': u'lanturn', u'resource_uri': u'api/v1/pokemon/171/'},
#     {u'name': u'pichu', u'resource_uri': u'api/v1/pokemon/172/'},
#     {u'name': u'cleffa', u'resource_uri': u'api/v1/pokemon/173/'},
#     {u'name': u'togepi', u'resource_uri': u'api/v1/pokemon/175/'},
#     {u'name': u'togetic', u'resource_uri': u'api/v1/pokemon/176/'},
#     {u'name': u'natu', u'resource_uri': u'api/v1/pokemon/177/'},
#     {u'name': u'xatu', u'resource_uri': u'api/v1/pokemon/178/'},
#     {u'name': u'mareep', u'resource_uri': u'api/v1/pokemon/179/'},
#     {u'name': u'bellossom', u'resource_uri': u'api/v1/pokemon/182/'},
#     {u'name': u'ampharos', u'resource_uri': u'api/v1/pokemon/181/'},
#     {u'name': u'marill', u'resource_uri': u'api/v1/pokemon/183/'},
#     {u'name': u'hoppip', u'resource_uri': u'api/v1/pokemon/187/'},
#     {u'name': u'sudowoodo', u'resource_uri': u'api/v1/pokemon/185/'},
#     {u'name': u'azumarill', u'resource_uri': u'api/v1/pokemon/184/'},
#     {u'name': u'politoed', u'resource_uri': u'api/v1/pokemon/186/'},
#     {u'name': u'skiploom', u'resource_uri': u'api/v1/pokemon/188/'},
#     {u'name': u'jumpluff', u'resource_uri': u'api/v1/pokemon/189/'},
#     {u'name': u'sunflora', u'resource_uri': u'api/v1/pokemon/192/'},
#     {u'name': u'yanma', u'resource_uri': u'api/v1/pokemon/193/'},
#     {u'name': u'aipom', u'resource_uri': u'api/v1/pokemon/190/'},
#     {u'name': u'sunkern', u'resource_uri': u'api/v1/pokemon/191/'},
#     {u'name': u'wooper', u'resource_uri': u'api/v1/pokemon/194/'},
#     {u'name': u'quagsire', u'resource_uri': u'api/v1/pokemon/195/'},
#     {u'name': u'murkrow', u'resource_uri': u'api/v1/pokemon/198/'},
#     {u'name': u'espeon', u'resource_uri': u'api/v1/pokemon/196/'},
#     {u'name': u'misdreavus', u'resource_uri': u'api/v1/pokemon/200/'},
#     {u'name': u'umbreon', u'resource_uri': u'api/v1/pokemon/197/'},
#     {u'name': u'unown', u'resource_uri': u'api/v1/pokemon/201/'},
#     {u'name': u'wobbuffet', u'resource_uri': u'api/v1/pokemon/202/'},
#     {u'name': u'girafarig', u'resource_uri': u'api/v1/pokemon/203/'},
#     {u'name': u'pineco', u'resource_uri': u'api/v1/pokemon/204/'},
#     {u'name': u'forretress', u'resource_uri': u'api/v1/pokemon/205/'},
#     {u'name': u'dunsparce', u'resource_uri': u'api/v1/pokemon/206/'},
#     {u'name': u'gligar', u'resource_uri': u'api/v1/pokemon/207/'},
#     {u'name': u'kabuto', u'resource_uri': u'api/v1/pokemon/140/'},
#     {u'name': u'aerodactyl', u'resource_uri': u'api/v1/pokemon/142/'},
#     {u'name': u'zapdos', u'resource_uri': u'api/v1/pokemon/145/'},
#     {u'name': u'shuckle', u'resource_uri': u'api/v1/pokemon/213/'},
#     {u'name': u'magcargo', u'resource_uri': u'api/v1/pokemon/219/'},
#     {u'name': u'heracross', u'resource_uri': u'api/v1/pokemon/214/'},
#     {u'name': u'sneasel', u'resource_uri': u'api/v1/pokemon/215/'},
#     {u'name': u'ursaring', u'resource_uri': u'api/v1/pokemon/217/'},
#     {u'name': u'slugma', u'resource_uri': u'api/v1/pokemon/218/'},
#     {u'name': u'swinub', u'resource_uri': u'api/v1/pokemon/220/'},
#     {u'name': u'delibird', u'resource_uri': u'api/v1/pokemon/225/'},
#     {u'name': u'piloswine', u'resource_uri': u'api/v1/pokemon/221/'},
#     {u'name': u'corsola', u'resource_uri': u'api/v1/pokemon/222/'},
#     {u'name': u'remoraid', u'resource_uri': u'api/v1/pokemon/223/'},
#     {u'name': u'houndour', u'resource_uri': u'api/v1/pokemon/228/'},
#     {u'name': u'octillery', u'resource_uri': u'api/v1/pokemon/224/'},
#     {u'name': u'mantine', u'resource_uri': u'api/v1/pokemon/226/'},
#     {u'name': u'porygon2', u'resource_uri': u'api/v1/pokemon/233/'},
#     {u'name': u'skarmory', u'resource_uri': u'api/v1/pokemon/227/'},
#     {u'name': u'houndoom', u'resource_uri': u'api/v1/pokemon/229/'},
#     {u'name': u'kingdra', u'resource_uri': u'api/v1/pokemon/230/'},
#     {u'name': u'phanpy', u'resource_uri': u'api/v1/pokemon/231/'},
#     {u'name': u'stantler', u'resource_uri': u'api/v1/pokemon/234/'},
#     {u'name': u'donphan', u'resource_uri': u'api/v1/pokemon/232/'},
#     {u'name': u'smoochum', u'resource_uri': u'api/v1/pokemon/238/'},
#     {u'name': u'smeargle', u'resource_uri': u'api/v1/pokemon/235/'},
#     {u'name': u'tyrogue', u'resource_uri': u'api/v1/pokemon/236/'},
#     {u'name': u'elekid', u'resource_uri': u'api/v1/pokemon/239/'},
#     {u'name': u'magby', u'resource_uri': u'api/v1/pokemon/240/'},
#     {u'name': u'miltank', u'resource_uri': u'api/v1/pokemon/241/'},
#     {u'name': u'blissey', u'resource_uri': u'api/v1/pokemon/242/'},
#     {u'name': u'raikou', u'resource_uri': u'api/v1/pokemon/243/'},
#     {u'name': u'suicune', u'resource_uri': u'api/v1/pokemon/245/'},
#     {u'name': u'entei', u'resource_uri': u'api/v1/pokemon/244/'},
#     {u'name': u'larvitar', u'resource_uri': u'api/v1/pokemon/246/'},
#     {u'name': u'pupitar', u'resource_uri': u'api/v1/pokemon/247/'},
#     {u'name': u'swampert', u'resource_uri': u'api/v1/pokemon/260/'},
#     {u'name': u'lugia', u'resource_uri': u'api/v1/pokemon/249/'},
#     {u'name': u'sceptile', u'resource_uri': u'api/v1/pokemon/254/'},
#     {u'name': u'ho-oh', u'resource_uri': u'api/v1/pokemon/250/'},
#     {u'name': u'celebi', u'resource_uri': u'api/v1/pokemon/251/'},
#     {u'name': u'treecko', u'resource_uri': u'api/v1/pokemon/252/'},
#     {u'name': u'grovyle', u'resource_uri': u'api/v1/pokemon/253/'},
#     {u'name': u'torchic', u'resource_uri': u'api/v1/pokemon/255/'},
#     {u'name': u'wurmple', u'resource_uri': u'api/v1/pokemon/265/'},
#     {u'name': u'combusken', u'resource_uri': u'api/v1/pokemon/256/'},
#     {u'name': u'blaziken', u'resource_uri': u'api/v1/pokemon/257/'},
#     {u'name': u'mudkip', u'resource_uri': u'api/v1/pokemon/258/'},
#     {u'name': u'marshtomp', u'resource_uri': u'api/v1/pokemon/259/'},
#     {u'name': u'poochyena', u'resource_uri': u'api/v1/pokemon/261/'},
#     {u'name': u'linoone', u'resource_uri': u'api/v1/pokemon/264/'},
#     {u'name': u'silcoon', u'resource_uri': u'api/v1/pokemon/266/'},
#     {u'name': u'mightyena', u'resource_uri': u'api/v1/pokemon/262/'},
#     {u'name': u'beautifly', u'resource_uri': u'api/v1/pokemon/267/'},
#     {u'name': u'cascoon', u'resource_uri': u'api/v1/pokemon/268/'},
#     {u'name': u'dustox', u'resource_uri': u'api/v1/pokemon/269/'},
#     {u'name': u'lotad', u'resource_uri': u'api/v1/pokemon/270/'},
#     {u'name': u'ludicolo', u'resource_uri': u'api/v1/pokemon/272/'},
#     {u'name': u'lombre', u'resource_uri': u'api/v1/pokemon/271/'},
#     {u'name': u'seedot', u'resource_uri': u'api/v1/pokemon/273/'},
#     {u'name': u'shiftry', u'resource_uri': u'api/v1/pokemon/275/'},
#     {u'name': u'nuzleaf', u'resource_uri': u'api/v1/pokemon/274/'},
#     {u'name': u'granbull', u'resource_uri': u'api/v1/pokemon/210/'},
#     {u'name': u'taillow', u'resource_uri': u'api/v1/pokemon/276/'},
#     {u'name': u'qwilfish', u'resource_uri': u'api/v1/pokemon/211/'},
#     {u'name': u'scizor', u'resource_uri': u'api/v1/pokemon/212/'},
#     {u'name': u'surskit', u'resource_uri': u'api/v1/pokemon/283/'},
#     {u'name': u'ralts', u'resource_uri': u'api/v1/pokemon/280/'},
#     {u'name': u'kirlia', u'resource_uri': u'api/v1/pokemon/281/'},
#     {u'name': u'masquerain', u'resource_uri': u'api/v1/pokemon/284/'},
#     {u'name': u'nincada', u'resource_uri': u'api/v1/pokemon/290/'},
#     {u'name': u'slaking', u'resource_uri': u'api/v1/pokemon/289/'},
#     {u'name': u'shroomish', u'resource_uri': u'api/v1/pokemon/285/'},
#     {u'name': u'breloom', u'resource_uri': u'api/v1/pokemon/286/'},
#     {u'name': u'vigoroth', u'resource_uri': u'api/v1/pokemon/288/'},
#     {u'name': u'ninjask', u'resource_uri': u'api/v1/pokemon/291/'},
#     {u'name': u'exploud', u'resource_uri': u'api/v1/pokemon/295/'},
#     {u'name': u'whismur', u'resource_uri': u'api/v1/pokemon/293/'},
#     {u'name': u'delcatty', u'resource_uri': u'api/v1/pokemon/301/'},
#     {u'name': u'loudred', u'resource_uri': u'api/v1/pokemon/294/'},
#     {u'name': u'nosepass', u'resource_uri': u'api/v1/pokemon/299/'},
#     {u'name': u'makuhita', u'resource_uri': u'api/v1/pokemon/296/'},
#     {u'name': u'hariyama', u'resource_uri': u'api/v1/pokemon/297/'},
#     {u'name': u'azurill', u'resource_uri': u'api/v1/pokemon/298/'},
#     {u'name': u'skitty', u'resource_uri': u'api/v1/pokemon/300/'},
#     {u'name': u'sableye', u'resource_uri': u'api/v1/pokemon/302/'},
#     {u'name': u'aron', u'resource_uri': u'api/v1/pokemon/304/'},
#     {u'name': u'mawile', u'resource_uri': u'api/v1/pokemon/303/'},
#     {u'name': u'plusle', u'resource_uri': u'api/v1/pokemon/311/'},
#     {u'name': u'aggron', u'resource_uri': u'api/v1/pokemon/306/'},
#     {u'name': u'lairon', u'resource_uri': u'api/v1/pokemon/305/'},
#     {u'name': u'medicham', u'resource_uri': u'api/v1/pokemon/308/'},
#     {u'name': u'electrike', u'resource_uri': u'api/v1/pokemon/309/'},
#     {u'name': u'manectric', u'resource_uri': u'api/v1/pokemon/310/'},
#     {u'name': u'volbeat', u'resource_uri': u'api/v1/pokemon/313/'},
#     {u'name': u'minun', u'resource_uri': u'api/v1/pokemon/312/'},
#     {u'name': u'illumise', u'resource_uri': u'api/v1/pokemon/314/'},
#     {u'name': u'roselia', u'resource_uri': u'api/v1/pokemon/315/'},
#     {u'name': u'gulpin', u'resource_uri': u'api/v1/pokemon/316/'},
#     {u'name': u'sharpedo', u'resource_uri': u'api/v1/pokemon/319/'},
#     {u'name': u'swalot', u'resource_uri': u'api/v1/pokemon/317/'},
#     {u'name': u'carvanha', u'resource_uri': u'api/v1/pokemon/318/'},
#     {u'name': u'wailmer', u'resource_uri': u'api/v1/pokemon/320/'},
#     {u'name': u'camerupt', u'resource_uri': u'api/v1/pokemon/323/'},
#     {u'name': u'numel', u'resource_uri': u'api/v1/pokemon/322/'},
#     {u'name': u'grumpig', u'resource_uri': u'api/v1/pokemon/326/'},
#     {u'name': u'torkoal', u'resource_uri': u'api/v1/pokemon/324/'},
#     {u'name': u'spoink', u'resource_uri': u'api/v1/pokemon/325/'},
#     {u'name': u'spinda', u'resource_uri': u'api/v1/pokemon/327/'},
#     {u'name': u'trapinch', u'resource_uri': u'api/v1/pokemon/328/'},
#     {u'name': u'vibrava', u'resource_uri': u'api/v1/pokemon/329/'},
#     {u'name': u'flygon', u'resource_uri': u'api/v1/pokemon/330/'},
#     {u'name': u'swablu', u'resource_uri': u'api/v1/pokemon/333/'},
#     {u'name': u'cacnea', u'resource_uri': u'api/v1/pokemon/331/'},
#     {u'name': u'cacturne', u'resource_uri': u'api/v1/pokemon/332/'},
#     {u'name': u'altaria', u'resource_uri': u'api/v1/pokemon/334/'},
#     {u'name': u'solrock', u'resource_uri': u'api/v1/pokemon/338/'},
#     {u'name': u'whiscash', u'resource_uri': u'api/v1/pokemon/340/'},
#     {u'name': u'lunatone', u'resource_uri': u'api/v1/pokemon/337/'},
#     {u'name': u'seviper', u'resource_uri': u'api/v1/pokemon/336/'},
#     {u'name': u'barboach', u'resource_uri': u'api/v1/pokemon/339/'},
#     {u'name': u'corphish', u'resource_uri': u'api/v1/pokemon/341/'},
#     {u'name': u'crawdaunt', u'resource_uri': u'api/v1/pokemon/342/'},
#     {u'name': u'baltoy', u'resource_uri': u'api/v1/pokemon/343/'},
#     {u'name': u'claydol', u'resource_uri': u'api/v1/pokemon/344/'},
#     {u'name': u'lileep', u'resource_uri': u'api/v1/pokemon/345/'},
#     {u'name': u'pelipper', u'resource_uri': u'api/v1/pokemon/279/'},
#     {u'name': u'wingull', u'resource_uri': u'api/v1/pokemon/278/'},
#     {u'name': u'slakoth', u'resource_uri': u'api/v1/pokemon/287/'},
#     {u'name': u'banette', u'resource_uri': u'api/v1/pokemon/354/'},
#     {u'name': u'milotic', u'resource_uri': u'api/v1/pokemon/350/'},
#     {u'name': u'duskull', u'resource_uri': u'api/v1/pokemon/355/'},
#     {u'name': u'kecleon', u'resource_uri': u'api/v1/pokemon/352/'},
#     {u'name': u'shuppet', u'resource_uri': u'api/v1/pokemon/353/'},
#     {u'name': u'dusclops', u'resource_uri': u'api/v1/pokemon/356/'},
#     {u'name': u'chimecho', u'resource_uri': u'api/v1/pokemon/358/'},
#     {u'name': u'absol', u'resource_uri': u'api/v1/pokemon/359/'},
#     {u'name': u'wynaut', u'resource_uri': u'api/v1/pokemon/360/'},
#     {u'name': u'snorunt', u'resource_uri': u'api/v1/pokemon/361/'},
#     {u'name': u'glalie', u'resource_uri': u'api/v1/pokemon/362/'},
#     {u'name': u'spheal', u'resource_uri': u'api/v1/pokemon/363/'},
#     {u'name': u'sealeo', u'resource_uri': u'api/v1/pokemon/364/'},
#     {u'name': u'relicanth', u'resource_uri': u'api/v1/pokemon/369/'},
#     {u'name': u'gorebyss', u'resource_uri': u'api/v1/pokemon/368/'},
#     {u'name': u'walrein', u'resource_uri': u'api/v1/pokemon/365/'},
#     {u'name': u'clamperl', u'resource_uri': u'api/v1/pokemon/366/'},
#     {u'name': u'huntail', u'resource_uri': u'api/v1/pokemon/367/'},
#     {u'name': u'bagon', u'resource_uri': u'api/v1/pokemon/371/'},
#     {u'name': u'luvdisc', u'resource_uri': u'api/v1/pokemon/370/'},
#     {u'name': u'shelgon', u'resource_uri': u'api/v1/pokemon/372/'},
#     {u'name': u'beldum', u'resource_uri': u'api/v1/pokemon/374/'},
#     {u'name': u'groudon', u'resource_uri': u'api/v1/pokemon/383/'},
#     {u'name': u'metang', u'resource_uri': u'api/v1/pokemon/375/'},
#     {u'name': u'registeel', u'resource_uri': u'api/v1/pokemon/379/'},
#     {u'name': u'metagross', u'resource_uri': u'api/v1/pokemon/376/'},
#     {u'name': u'regirock', u'resource_uri': u'api/v1/pokemon/377/'},
#     {u'name': u'regice', u'resource_uri': u'api/v1/pokemon/378/'},
#     {u'name': u'latias', u'resource_uri': u'api/v1/pokemon/380/'},
#     {u'name': u'latios', u'resource_uri': u'api/v1/pokemon/381/'},
#     {u'name': u'kyogre', u'resource_uri': u'api/v1/pokemon/382/'},
#     {u'name': u'rayquaza', u'resource_uri': u'api/v1/pokemon/384/'},
#     {u'name': u'jirachi', u'resource_uri': u'api/v1/pokemon/385/'},
#     {u'name': u'turtwig', u'resource_uri': u'api/v1/pokemon/387/'},
#     {u'name': u'torterra', u'resource_uri': u'api/v1/pokemon/389/'},
#     {u'name': u'grotle', u'resource_uri': u'api/v1/pokemon/388/'},
#     {u'name': u'chimchar', u'resource_uri': u'api/v1/pokemon/390/'},
#     {u'name': u'staraptor', u'resource_uri': u'api/v1/pokemon/398/'},
#     {u'name': u'shinx', u'resource_uri': u'api/v1/pokemon/403/'},
#     {u'name': u'monferno', u'resource_uri': u'api/v1/pokemon/391/'},
#     {u'name': u'infernape', u'resource_uri': u'api/v1/pokemon/392/'},
#     {u'name': u'piplup', u'resource_uri': u'api/v1/pokemon/393/'},
#     {u'name': u'empoleon', u'resource_uri': u'api/v1/pokemon/395/'},
#     {u'name': u'prinplup', u'resource_uri': u'api/v1/pokemon/394/'},
#     {u'name': u'starly', u'resource_uri': u'api/v1/pokemon/396/'},
#     {u'name': u'staravia', u'resource_uri': u'api/v1/pokemon/397/'},
#     {u'name': u'kricketot', u'resource_uri': u'api/v1/pokemon/401/'},
#     {u'name': u'bidoof', u'resource_uri': u'api/v1/pokemon/399/'},
#     {u'name': u'kricketune', u'resource_uri': u'api/v1/pokemon/402/'},
#     {u'name': u'luxio', u'resource_uri': u'api/v1/pokemon/404/'},
#     {u'name': u'luxray', u'resource_uri': u'api/v1/pokemon/405/'},
#     {u'name': u'budew', u'resource_uri': u'api/v1/pokemon/406/'},
#     {u'name': u'roserade', u'resource_uri': u'api/v1/pokemon/407/'},
#     {u'name': u'cranidos', u'resource_uri': u'api/v1/pokemon/408/'},
#     {u'name': u'rampardos', u'resource_uri': u'api/v1/pokemon/409/'},
#     {u'name': u'shieldon', u'resource_uri': u'api/v1/pokemon/410/'},
#     {u'name': u'bastiodon', u'resource_uri': u'api/v1/pokemon/411/'},
#     {u'name': u'burmy', u'resource_uri': u'api/v1/pokemon/412/'},
#     {u'name': u'mothim', u'resource_uri': u'api/v1/pokemon/414/'},
#     {u'name': u'feebas', u'resource_uri': u'api/v1/pokemon/349/'},
#     {u'name': u'anorith', u'resource_uri': u'api/v1/pokemon/347/'},
#     {u'name': u'armaldo', u'resource_uri': u'api/v1/pokemon/348/'},
#     {u'name': u'castform', u'resource_uri': u'api/v1/pokemon/351/'},
#     {u'name': u'cherubi', u'resource_uri': u'api/v1/pokemon/420/'},
#     {u'name': u'mismagius', u'resource_uri': u'api/v1/pokemon/429/'},
#     {u'name': u'ambipom', u'resource_uri': u'api/v1/pokemon/424/'},
#     {u'name': u'cherrim', u'resource_uri': u'api/v1/pokemon/421/'},
#     {u'name': u'gastrodon', u'resource_uri': u'api/v1/pokemon/423/'},
#     {u'name': u'drifblim', u'resource_uri': u'api/v1/pokemon/426/'},
#     {u'name': u'drifloon', u'resource_uri': u'api/v1/pokemon/425/'},
#     {u'name': u'buneary', u'resource_uri': u'api/v1/pokemon/427/'},
#     {u'name': u'lopunny', u'resource_uri': u'api/v1/pokemon/428/'},
#     {u'name': u'chingling', u'resource_uri': u'api/v1/pokemon/433/'},
#     {u'name': u'honchkrow', u'resource_uri': u'api/v1/pokemon/430/'},
#     {u'name': u'glameow', u'resource_uri': u'api/v1/pokemon/431/'},
#     {u'name': u'purugly', u'resource_uri': u'api/v1/pokemon/432/'},
#     {u'name': u'stunky', u'resource_uri': u'api/v1/pokemon/434/'},
#     {u'name': u'skuntank', u'resource_uri': u'api/v1/pokemon/435/'},
#     {u'name': u'happiny', u'resource_uri': u'api/v1/pokemon/440/'},
#     {u'name': u'bronzor', u'resource_uri': u'api/v1/pokemon/436/'},
#     {u'name': u'bronzong', u'resource_uri': u'api/v1/pokemon/437/'},
#     {u'name': u'bonsly', u'resource_uri': u'api/v1/pokemon/438/'},
#     {u'name': u'mime-jr', u'resource_uri': u'api/v1/pokemon/439/'},
#     {u'name': u'spiritomb', u'resource_uri': u'api/v1/pokemon/442/'},
#     {u'name': u'gible', u'resource_uri': u'api/v1/pokemon/443/'},
#     {u'name': u'lucario', u'resource_uri': u'api/v1/pokemon/448/'},
#     {u'name': u'gabite', u'resource_uri': u'api/v1/pokemon/444/'},
#     {u'name': u'garchomp', u'resource_uri': u'api/v1/pokemon/445/'},
#     {u'name': u'drapion', u'resource_uri': u'api/v1/pokemon/452/'},
#     {u'name': u'hippopotas', u'resource_uri': u'api/v1/pokemon/449/'},
#     {u'name': u'munchlax', u'resource_uri': u'api/v1/pokemon/446/'},
#     {u'name': u'riolu', u'resource_uri': u'api/v1/pokemon/447/'},
#     {u'name': u'hippowdon', u'resource_uri': u'api/v1/pokemon/450/'},
#     {u'name': u'croagunk', u'resource_uri': u'api/v1/pokemon/453/'},
#     {u'name': u'toxicroak', u'resource_uri': u'api/v1/pokemon/454/'},
#     {u'name': u'carnivine', u'resource_uri': u'api/v1/pokemon/455/'},
#     {u'name': u'lumineon', u'resource_uri': u'api/v1/pokemon/457/'},
#     {u'name': u'finneon', u'resource_uri': u'api/v1/pokemon/456/'},
#     {u'name': u'mantyke', u'resource_uri': u'api/v1/pokemon/458/'},
#     {u'name': u'snover', u'resource_uri': u'api/v1/pokemon/459/'},
#     {u'name': u'abomasnow', u'resource_uri': u'api/v1/pokemon/460/'},
#     {u'name': u'electivire', u'resource_uri': u'api/v1/pokemon/466/'},
#     {u'name': u'weavile', u'resource_uri': u'api/v1/pokemon/461/'},
#     {u'name': u'lickilicky', u'resource_uri': u'api/v1/pokemon/463/'},
#     {u'name': u'rhyperior', u'resource_uri': u'api/v1/pokemon/464/'},
#     {u'name': u'magnezone', u'resource_uri': u'api/v1/pokemon/462/'},
#     {u'name': u'magmortar', u'resource_uri': u'api/v1/pokemon/467/'},
#     {u'name': u'togekiss', u'resource_uri': u'api/v1/pokemon/468/'},
#     {u'name': u'yanmega', u'resource_uri': u'api/v1/pokemon/469/'},
#     {u'name': u'leafeon', u'resource_uri': u'api/v1/pokemon/470/'},
#     {u'name': u'glaceon', u'resource_uri': u'api/v1/pokemon/471/'},
#     {u'name': u'gliscor', u'resource_uri': u'api/v1/pokemon/472/'},
#     {u'name': u'mamoswine', u'resource_uri': u'api/v1/pokemon/473/'},
#     {u'name': u'porygon-z', u'resource_uri': u'api/v1/pokemon/474/'},
#     {u'name': u'gallade', u'resource_uri': u'api/v1/pokemon/475/'},
#     {u'name': u'probopass', u'resource_uri': u'api/v1/pokemon/476/'},
#     {u'name': u'dusknoir', u'resource_uri': u'api/v1/pokemon/477/'},
#     {u'name': u'froslass', u'resource_uri': u'api/v1/pokemon/478/'},
#     {u'name': u'rotom', u'resource_uri': u'api/v1/pokemon/479/'},
#     {u'name': u'uxie', u'resource_uri': u'api/v1/pokemon/480/'},
#     {u'name': u'mesprit', u'resource_uri': u'api/v1/pokemon/481/'},
#     {u'name': u'dialga', u'resource_uri': u'api/v1/pokemon/483/'},
#     {u'name': u'vespiquen', u'resource_uri': u'api/v1/pokemon/416/'},
#     {u'name': u'pachirisu', u'resource_uri': u'api/v1/pokemon/417/'},
#     {u'name': u'buizel', u'resource_uri': u'api/v1/pokemon/418/'},
#     {u'name': u'floatzel', u'resource_uri': u'api/v1/pokemon/419/'},
#     {u'name': u'victini', u'resource_uri': u'api/v1/pokemon/494/'},
#     {u'name': u'darkrai', u'resource_uri': u'api/v1/pokemon/491/'},
#     {u'name': u'shaymin-land', u'resource_uri': u'api/v1/pokemon/492/'},
#     {u'name': u'arceus', u'resource_uri': u'api/v1/pokemon/493/'},
#     {u'name': u'snivy', u'resource_uri': u'api/v1/pokemon/495/'},
#     {u'name': u'serperior', u'resource_uri': u'api/v1/pokemon/497/'},
#     {u'name': u'servine', u'resource_uri': u'api/v1/pokemon/496/'},
#     {u'name': u'patrat', u'resource_uri': u'api/v1/pokemon/504/'},
#     {u'name': u'tepig', u'resource_uri': u'api/v1/pokemon/498/'},
#     {u'name': u'pignite', u'resource_uri': u'api/v1/pokemon/499/'},
#     {u'name': u'emboar', u'resource_uri': u'api/v1/pokemon/500/'},
#     {u'name': u'oshawott', u'resource_uri': u'api/v1/pokemon/501/'},
#     {u'name': u'dewott', u'resource_uri': u'api/v1/pokemon/502/'},
#     {u'name': u'watchog', u'resource_uri': u'api/v1/pokemon/505/'},
#     {u'name': u'lillipup', u'resource_uri': u'api/v1/pokemon/506/'},
#     {u'name': u'herdier', u'resource_uri': u'api/v1/pokemon/507/'},
#     {u'name': u'stoutland', u'resource_uri': u'api/v1/pokemon/508/'},
#     {u'name': u'purrloin', u'resource_uri': u'api/v1/pokemon/509/'},
#     {u'name': u'liepard', u'resource_uri': u'api/v1/pokemon/510/'},
#     {u'name': u'pansage', u'resource_uri': u'api/v1/pokemon/511/'},
#     {u'name': u'simisage', u'resource_uri': u'api/v1/pokemon/512/'},
#     {u'name': u'pansear', u'resource_uri': u'api/v1/pokemon/513/'},
#     {u'name': u'panpour', u'resource_uri': u'api/v1/pokemon/515/'},
#     {u'name': u'simipour', u'resource_uri': u'api/v1/pokemon/516/'},
#     {u'name': u'roggenrola', u'resource_uri': u'api/v1/pokemon/524/'},
#     {u'name': u'munna', u'resource_uri': u'api/v1/pokemon/517/'},
#     {u'name': u'musharna', u'resource_uri': u'api/v1/pokemon/518/'},
#     {u'name': u'pidove', u'resource_uri': u'api/v1/pokemon/519/'},
#     {u'name': u'tranquill', u'resource_uri': u'api/v1/pokemon/520/'},
#     {u'name': u'unfezant', u'resource_uri': u'api/v1/pokemon/521/'},
#     {u'name': u'blitzle', u'resource_uri': u'api/v1/pokemon/522/'},
#     {u'name': u'zebstrika', u'resource_uri': u'api/v1/pokemon/523/'},
#     {u'name': u'boldore', u'resource_uri': u'api/v1/pokemon/525/'},
#     {u'name': u'gigalith', u'resource_uri': u'api/v1/pokemon/526/'},
#     {u'name': u'woobat', u'resource_uri': u'api/v1/pokemon/527/'},
#     {u'name': u'swoobat', u'resource_uri': u'api/v1/pokemon/528/'},
#     {u'name': u'drilbur', u'resource_uri': u'api/v1/pokemon/529/'},
#     {u'name': u'excadrill', u'resource_uri': u'api/v1/pokemon/530/'},
#     {u'name': u'audino', u'resource_uri': u'api/v1/pokemon/531/'},
#     {u'name': u'conkeldurr', u'resource_uri': u'api/v1/pokemon/534/'},
#     {u'name': u'timburr', u'resource_uri': u'api/v1/pokemon/532/'},
#     {u'name': u'tympole', u'resource_uri': u'api/v1/pokemon/535/'},
#     {u'name': u'palpitoad', u'resource_uri': u'api/v1/pokemon/536/'},
#     {u'name': u'seismitoad', u'resource_uri': u'api/v1/pokemon/537/'},
#     {u'name': u'throh', u'resource_uri': u'api/v1/pokemon/538/'},
#     {u'name': u'sawk', u'resource_uri': u'api/v1/pokemon/539/'},
#     {u'name': u'sewaddle', u'resource_uri': u'api/v1/pokemon/540/'},
#     {u'name': u'swadloon', u'resource_uri': u'api/v1/pokemon/541/'},
#     {u'name': u'venipede', u'resource_uri': u'api/v1/pokemon/543/'},
#     {u'name': u'whirlipede', u'resource_uri': u'api/v1/pokemon/544/'},
#     {u'name': u'basculin-red-striped',
#      u'resource_uri': u'api/v1/pokemon/550/'},
#     {u'name': u'scolipede', u'resource_uri': u'api/v1/pokemon/545/'},
#     {u'name': u'cottonee', u'resource_uri': u'api/v1/pokemon/546/'},
#     {u'name': u'whimsicott', u'resource_uri': u'api/v1/pokemon/547/'},
#     {u'name': u'petilil', u'resource_uri': u'api/v1/pokemon/548/'},
#     {u'name': u'lilligant', u'resource_uri': u'api/v1/pokemon/549/'},
#     {u'name': u'sandile', u'resource_uri': u'api/v1/pokemon/551/'},
#     {u'name': u'krokorok', u'resource_uri': u'api/v1/pokemon/552/'},
#     {u'name': u'manaphy', u'resource_uri': u'api/v1/pokemon/490/'},
#     {u'name': u'regigigas', u'resource_uri': u'api/v1/pokemon/486/'},
#     {u'name': u'giratina-altered', u'resource_uri': u'api/v1/pokemon/487/'},
#     {u'name': u'cofagrigus', u'resource_uri': u'api/v1/pokemon/563/'},
#     {u'name': u'crustle', u'resource_uri': u'api/v1/pokemon/558/'},
#     {u'name': u'tirtouga', u'resource_uri': u'api/v1/pokemon/564/'},
#     {u'name': u'scraggy', u'resource_uri': u'api/v1/pokemon/559/'},
#     {u'name': u'scrafty', u'resource_uri': u'api/v1/pokemon/560/'},
#     {u'name': u'sigilyph', u'resource_uri': u'api/v1/pokemon/561/'},
#     {u'name': u'yamask', u'resource_uri': u'api/v1/pokemon/562/'},
#     {u'name': u'zoroark', u'resource_uri': u'api/v1/pokemon/571/'},
#     {u'name': u'carracosta', u'resource_uri': u'api/v1/pokemon/565/'},
#     {u'name': u'zorua', u'resource_uri': u'api/v1/pokemon/570/'},
#     {u'name': u'archen', u'resource_uri': u'api/v1/pokemon/566/'},
#     {u'name': u'archeops', u'resource_uri': u'api/v1/pokemon/567/'},
#     {u'name': u'trubbish', u'resource_uri': u'api/v1/pokemon/568/'},
#     {u'name': u'minccino', u'resource_uri': u'api/v1/pokemon/572/'},
#     {u'name': u'cinccino', u'resource_uri': u'api/v1/pokemon/573/'},
#     {u'name': u'gothita', u'resource_uri': u'api/v1/pokemon/574/'},
#     {u'name': u'gothorita', u'resource_uri': u'api/v1/pokemon/575/'},
#     {u'name': u'gothitelle', u'resource_uri': u'api/v1/pokemon/576/'},
#     {u'name': u'solosis', u'resource_uri': u'api/v1/pokemon/577/'},
#     {u'name': u'duosion', u'resource_uri': u'api/v1/pokemon/578/'},
#     {u'name': u'vanillite', u'resource_uri': u'api/v1/pokemon/582/'},
#     {u'name': u'reuniclus', u'resource_uri': u'api/v1/pokemon/579/'},
#     {u'name': u'swanna', u'resource_uri': u'api/v1/pokemon/581/'},
#     {u'name': u'vanillish', u'resource_uri': u'api/v1/pokemon/583/'},
#     {u'name': u'vanilluxe', u'resource_uri': u'api/v1/pokemon/584/'},
#     {u'name': u'deerling', u'resource_uri': u'api/v1/pokemon/585/'},
#     {u'name': u'sawsbuck', u'resource_uri': u'api/v1/pokemon/586/'},
#     {u'name': u'karrablast', u'resource_uri': u'api/v1/pokemon/588/'},
#     {u'name': u'emolga', u'resource_uri': u'api/v1/pokemon/587/'},
#     {u'name': u'foongus', u'resource_uri': u'api/v1/pokemon/590/'},
#     {u'name': u'escavalier', u'resource_uri': u'api/v1/pokemon/589/'},
#     {u'name': u'amoonguss', u'resource_uri': u'api/v1/pokemon/591/'},
#     {u'name': u'frillish', u'resource_uri': u'api/v1/pokemon/592/'},
#     {u'name': u'galvantula', u'resource_uri': u'api/v1/pokemon/596/'},
#     {u'name': u'jellicent', u'resource_uri': u'api/v1/pokemon/593/'},
#     {u'name': u'joltik', u'resource_uri': u'api/v1/pokemon/595/'},
#     {u'name': u'alomomola', u'resource_uri': u'api/v1/pokemon/594/'},
#     {u'name': u'ferroseed', u'resource_uri': u'api/v1/pokemon/597/'},
#     {u'name': u'ferrothorn', u'resource_uri': u'api/v1/pokemon/598/'},
#     {u'name': u'tynamo', u'resource_uri': u'api/v1/pokemon/602/'},
#     {u'name': u'klink', u'resource_uri': u'api/v1/pokemon/599/'},
#     {u'name': u'eelektrik', u'resource_uri': u'api/v1/pokemon/603/'},
#     {u'name': u'klang', u'resource_uri': u'api/v1/pokemon/600/'},
#     {u'name': u'eelektross', u'resource_uri': u'api/v1/pokemon/604/'},
#     {u'name': u'elgyem', u'resource_uri': u'api/v1/pokemon/605/'},
#     {u'name': u'beheeyem', u'resource_uri': u'api/v1/pokemon/606/'},
#     {u'name': u'litwick', u'resource_uri': u'api/v1/pokemon/607/'},
#     {u'name': u'lampent', u'resource_uri': u'api/v1/pokemon/608/'},
#     {u'name': u'chandelure', u'resource_uri': u'api/v1/pokemon/609/'},
#     {u'name': u'axew', u'resource_uri': u'api/v1/pokemon/610/'},
#     {u'name': u'cubchoo', u'resource_uri': u'api/v1/pokemon/613/'},
#     {u'name': u'haxorus', u'resource_uri': u'api/v1/pokemon/612/'},
#     {u'name': u'beartic', u'resource_uri': u'api/v1/pokemon/614/'},
#     {u'name': u'cryogonal', u'resource_uri': u'api/v1/pokemon/615/'},
#     {u'name': u'shelmet', u'resource_uri': u'api/v1/pokemon/616/'},
#     {u'name': u'accelgor', u'resource_uri': u'api/v1/pokemon/617/'},
#     {u'name': u'stunfisk', u'resource_uri': u'api/v1/pokemon/618/'},
#     {u'name': u'mienfoo', u'resource_uri': u'api/v1/pokemon/619/'},
#     {u'name': u'mienshao', u'resource_uri': u'api/v1/pokemon/620/'},
#     {u'name': u'darumaka', u'resource_uri': u'api/v1/pokemon/554/'},
#     {u'name': u'maractus', u'resource_uri': u'api/v1/pokemon/556/'},
#     {u'name': u'darmanitan-standard', u'resource_uri': u'api/v1/pokemon/555/'},
#     {u'name': u'dwebble', u'resource_uri': u'api/v1/pokemon/557/'},
#     {u'name': u'bisharp', u'resource_uri': u'api/v1/pokemon/625/'},
#     {u'name': u'bouffalant', u'resource_uri': u'api/v1/pokemon/626/'},
#     {u'name': u'rufflet', u'resource_uri': u'api/v1/pokemon/627/'},
#     {u'name': u'deino', u'resource_uri': u'api/v1/pokemon/633/'},
#     {u'name': u'vullaby', u'resource_uri': u'api/v1/pokemon/629/'},
#     {u'name': u'mandibuzz', u'resource_uri': u'api/v1/pokemon/630/'},
#     {u'name': u'heatmor', u'resource_uri': u'api/v1/pokemon/631/'},
#     {u'name': u'durant', u'resource_uri': u'api/v1/pokemon/632/'},
#     {u'name': u'chesnaught', u'resource_uri': u'api/v1/pokemon/652/'},
#     {u'name': u'hydreigon', u'resource_uri': u'api/v1/pokemon/635/'},
#     {u'name': u'larvesta', u'resource_uri': u'api/v1/pokemon/636/'},
#     {u'name': u'volcarona', u'resource_uri': u'api/v1/pokemon/637/'},
#     {u'name': u'cobalion', u'resource_uri': u'api/v1/pokemon/638/'},
#     {u'name': u'terrakion', u'resource_uri': u'api/v1/pokemon/639/'},
#     {u'name': u'thundurus-incarnate', u'resource_uri': u'api/v1/pokemon/642/'},
#     {u'name': u'virizion', u'resource_uri': u'api/v1/pokemon/640/'},
#     {u'name': u'reshiram', u'resource_uri': u'api/v1/pokemon/643/'},
#     {u'name': u'zekrom', u'resource_uri': u'api/v1/pokemon/644/'},
#     {u'name': u'landorus-incarnate', u'resource_uri': u'api/v1/pokemon/645/'},
#     {u'name': u'kyurem', u'resource_uri': u'api/v1/pokemon/646/'},
#     {u'name': u'keldeo-ordinary', u'resource_uri': u'api/v1/pokemon/647/'},
#     {u'name': u'meloetta-aria', u'resource_uri': u'api/v1/pokemon/648/'},
#     {u'name': u'genesect', u'resource_uri': u'api/v1/pokemon/649/'},
#     {u'name': u'chespin', u'resource_uri': u'api/v1/pokemon/650/'},
#     {u'name': u'quilladin', u'resource_uri': u'api/v1/pokemon/651/'},
#     {u'name': u'fennekin', u'resource_uri': u'api/v1/pokemon/653/'},
#     {u'name': u'braixen', u'resource_uri': u'api/v1/pokemon/654/'},
#     {u'name': u'fletchinder', u'resource_uri': u'api/v1/pokemon/662/'},
#     {u'name': u'delphox', u'resource_uri': u'api/v1/pokemon/655/'},
#     {u'name': u'froakie', u'resource_uri': u'api/v1/pokemon/656/'},
#     {u'name': u'frogadier', u'resource_uri': u'api/v1/pokemon/657/'},
#     {u'name': u'greninja', u'resource_uri': u'api/v1/pokemon/658/'},
#     {u'name': u'bunnelby', u'resource_uri': u'api/v1/pokemon/659/'},
#     {u'name': u'diggersby', u'resource_uri': u'api/v1/pokemon/660/'},
#     {u'name': u'fletchling', u'resource_uri': u'api/v1/pokemon/661/'},
#     {u'name': u'talonflame', u'resource_uri': u'api/v1/pokemon/663/'},
#     {u'name': u'vivillon', u'resource_uri': u'api/v1/pokemon/666/'},
#     {u'name': u'scatterbug', u'resource_uri': u'api/v1/pokemon/664/'},
#     {u'name': u'florges', u'resource_uri': u'api/v1/pokemon/671/'},
#     {u'name': u'spewpa', u'resource_uri': u'api/v1/pokemon/665/'},
#     {u'name': u'litleo', u'resource_uri': u'api/v1/pokemon/667/'},
#     {u'name': u'flabebe', u'resource_uri': u'api/v1/pokemon/669/'},
#     {u'name': u'floette', u'resource_uri': u'api/v1/pokemon/670/'},
#     {u'name': u'skiddo', u'resource_uri': u'api/v1/pokemon/672/'},
#     {u'name': u'gogoat', u'resource_uri': u'api/v1/pokemon/673/'},
#     {u'name': u'pancham', u'resource_uri': u'api/v1/pokemon/674/'},
#     {u'name': u'meowstic-male', u'resource_uri': u'api/v1/pokemon/678/'},
#     {u'name': u'furfrou', u'resource_uri': u'api/v1/pokemon/676/'},
#     {u'name': u'espurr', u'resource_uri': u'api/v1/pokemon/677/'},
#     {u'name': u'honedge', u'resource_uri': u'api/v1/pokemon/679/'},
#     {u'name': u'doublade', u'resource_uri': u'api/v1/pokemon/680/'},
#     {u'name': u'spritzee', u'resource_uri': u'api/v1/pokemon/682/'},
#     {u'name': u'swirlix', u'resource_uri': u'api/v1/pokemon/684/'},
#     {u'name': u'aromatisse', u'resource_uri': u'api/v1/pokemon/683/'},
#     {u'name': u'slurpuff', u'resource_uri': u'api/v1/pokemon/685/'},
#     {u'name': u'inkay', u'resource_uri': u'api/v1/pokemon/686/'},
#     {u'name': u'malamar', u'resource_uri': u'api/v1/pokemon/687/'},
#     {u'name': u'binacle', u'resource_uri': u'api/v1/pokemon/688/'},
#     {u'name': u'aegislash', u'resource_uri': u'api/v1/pokemon/681/'},
#     {u'name': u'golett', u'resource_uri': u'api/v1/pokemon/622/'},
#     {u'name': u'golurk', u'resource_uri': u'api/v1/pokemon/623/'},
#     {u'name': u'pawniard', u'resource_uri': u'api/v1/pokemon/624/'},
#     {u'name': u'braviary', u'resource_uri': u'api/v1/pokemon/628/'},
#     {u'name': u'clawitzer', u'resource_uri': u'api/v1/pokemon/693/'},
#     {u'name': u'sylveon', u'resource_uri': u'api/v1/pokemon/700/'},
#     {u'name': u'tyrunt', u'resource_uri': u'api/v1/pokemon/696/'},
#     {u'name': u'dedenne', u'resource_uri': u'api/v1/pokemon/702/'},
#     {u'name': u'tyrantrum', u'resource_uri': u'api/v1/pokemon/697/'},
#     {u'name': u'carbink', u'resource_uri': u'api/v1/pokemon/703/'},
#     {u'name': u'amaura', u'resource_uri': u'api/v1/pokemon/698/'},
#     {u'name': u'aurorus', u'resource_uri': u'api/v1/pokemon/699/'},
#     {u'name': u'hawlucha', u'resource_uri': u'api/v1/pokemon/701/'},
#     {u'name': u'goodra', u'resource_uri': u'api/v1/pokemon/706/'},
#     {u'name': u'klefki', u'resource_uri': u'api/v1/pokemon/707/'},
#     {u'name': u'goomy', u'resource_uri': u'api/v1/pokemon/704/'},
#     {u'name': u'phantump', u'resource_uri': u'api/v1/pokemon/708/'},
#     {u'name': u'sliggoo', u'resource_uri': u'api/v1/pokemon/705/'},
#     {u'name': u'noibat', u'resource_uri': u'api/v1/pokemon/714/'},
#     {u'name': u'trevenant', u'resource_uri': u'api/v1/pokemon/709/'},
#     {u'name': u'pumpkaboo-average', u'resource_uri': u'api/v1/pokemon/710/'},
#     {u'name': u'bergmite', u'resource_uri': u'api/v1/pokemon/712/'},
#     {u'name': u'gourgeist-average', u'resource_uri': u'api/v1/pokemon/711/'},
#     {u'name': u'avalugg', u'resource_uri': u'api/v1/pokemon/713/'},
#     {u'name': u'noivern', u'resource_uri': u'api/v1/pokemon/715/'},
#     {u'name': u'zygarde', u'resource_uri': u'api/v1/pokemon/718/'},
#     {u'name': u'xerneas', u'resource_uri': u'api/v1/pokemon/716/'},
#     {u'name': u'yveltal', u'resource_uri': u'api/v1/pokemon/717/'},
#     {u'name': u'deoxys-defense', u'resource_uri': u'api/v1/pokemon/10002/'},
#     {u'name': u'deoxys-attack', u'resource_uri': u'api/v1/pokemon/10001/'},
#     {u'name': u'skrelp', u'resource_uri': u'api/v1/pokemon/690/'},
#     {u'name': u'heliolisk', u'resource_uri': u'api/v1/pokemon/695/'},
#     {u'name': u'deoxys-speed', u'resource_uri': u'api/v1/pokemon/10003/'},
#     {u'name': u'wormadam-sandy', u'resource_uri': u'api/v1/pokemon/10004/'},
#     {u'name': u'castform-rainy', u'resource_uri': u'api/v1/pokemon/10014/'},
#     {u'name': u'rotom-heat', u'resource_uri': u'api/v1/pokemon/10008/'},
#     {u'name': u'wormadam-trash', u'resource_uri': u'api/v1/pokemon/10005/'},
#     {u'name': u'shaymin-sky', u'resource_uri': u'api/v1/pokemon/10006/'},
#     {u'name': u'rotom-wash', u'resource_uri': u'api/v1/pokemon/10009/'},
#     {u'name': u'rotom-frost', u'resource_uri': u'api/v1/pokemon/10010/'},
#     {u'name': u'rotom-fan', u'resource_uri': u'api/v1/pokemon/10011/'},
#     {u'name': u'rotom-mow', u'resource_uri': u'api/v1/pokemon/10012/'},
#     {u'name': u'castform-sunny', u'resource_uri': u'api/v1/pokemon/10013/'},
#     {u'name': u'basculin-blue-striped',
#      u'resource_uri': u'api/v1/pokemon/10016/'},
#     {u'name': u'darmanitan-zen', u'resource_uri': u'api/v1/pokemon/10017/'},
#     {u'name': u'meloetta-pirouette',
#      u'resource_uri': u'api/v1/pokemon/10018/'},
#     {u'name': u'thundurus-therian', u'resource_uri': u'api/v1/pokemon/10020/'},
#     {u'name': u'tornadus-therian', u'resource_uri': u'api/v1/pokemon/10019/'},
#     {u'name': u'landorus-therian', u'resource_uri': u'api/v1/pokemon/10021/'},
#     {u'name': u'kyurem-white', u'resource_uri': u'api/v1/pokemon/10023/'},
#     {u'name': u'aegislash-blade', u'resource_uri': u'api/v1/pokemon/10026/'},
#     {u'name': u'kyurem-black', u'resource_uri': u'api/v1/pokemon/10022/'},
#     {u'name': u'keldeo-resolute', u'resource_uri': u'api/v1/pokemon/10024/'},
#     {u'name': u'meowstic-female', u'resource_uri': u'api/v1/pokemon/10025/'},
#     {u'name': u'pumpkaboo-small', u'resource_uri': u'api/v1/pokemon/10027/'},
#     {u'name': u'alakazam-mega', u'resource_uri': u'api/v1/pokemon/10037/'},
#     {u'name': u'pumpkaboo-large', u'resource_uri': u'api/v1/pokemon/10028/'},
#     {u'name': u'pumpkaboo-super', u'resource_uri': u'api/v1/pokemon/10029/'},
#     {u'name': u'gourgeist-small', u'resource_uri': u'api/v1/pokemon/10030/'},
#     {u'name': u'gourgeist-large', u'resource_uri': u'api/v1/pokemon/10031/'},
#     {u'name': u'gourgeist-super', u'resource_uri': u'api/v1/pokemon/10032/'},
#     {u'name': u'venusaur-mega', u'resource_uri': u'api/v1/pokemon/10033/'},
#     {u'name': u'charizard-mega-x', u'resource_uri': u'api/v1/pokemon/10034/'},
#     {u'name': u'charizard-mega-y', u'resource_uri': u'api/v1/pokemon/10035/'},
#     {u'name': u'blastoise-mega', u'resource_uri': u'api/v1/pokemon/10036/'},
#     {u'name': u'clauncher', u'resource_uri': u'api/v1/pokemon/692/'},
#     {u'name': u'shellder', u'resource_uri': u'api/v1/pokemon/90/'},
#     {u'name': u'alakazam', u'resource_uri': u'api/v1/pokemon/65/'},
#     {u'name': u'kabutops', u'resource_uri': u'api/v1/pokemon/141/'},
#     {u'name': u'leavanny', u'resource_uri': u'api/v1/pokemon/542/'},
#     {u'name': u'snubbull', u'resource_uri': u'api/v1/pokemon/209/'},
#     {u'name': u'dragonite', u'resource_uri': u'api/v1/pokemon/149/'},
#     {u'name': u'steelix', u'resource_uri': u'api/v1/pokemon/208/'},
#     {u'name': u'tyranitar', u'resource_uri': u'api/v1/pokemon/248/'},
#     {u'name': u'swellow', u'resource_uri': u'api/v1/pokemon/277/'},
#     {u'name': u'wailord', u'resource_uri': u'api/v1/pokemon/321/'},
#     {u'name': u'cradily', u'resource_uri': u'api/v1/pokemon/346/'},
#     {u'name': u'deoxys-normal', u'resource_uri': u'api/v1/pokemon/386/'},
#     {u'name': u'azelf', u'resource_uri': u'api/v1/pokemon/482/'},
#     {u'name': u'wormadam-plant', u'resource_uri': u'api/v1/pokemon/413/'},
#     {u'name': u'krookodile', u'resource_uri': u'api/v1/pokemon/553/'},
#     {u'name': u'ducklett', u'resource_uri': u'api/v1/pokemon/580/'},
#     {u'name': u'gengar-mega', u'resource_uri': u'api/v1/pokemon/10038/'},
#     {u'name': u'pinsir-mega', u'resource_uri': u'api/v1/pokemon/10040/'},
#     {u'name': u'kangaskhan-mega', u'resource_uri': u'api/v1/pokemon/10039/'},
#     {u'name': u'barbaracle', u'resource_uri': u'api/v1/pokemon/689/'},
#     {u'name': u'gyarados-mega', u'resource_uri': u'api/v1/pokemon/10041/'},
#     {u'name': u'ampharos-mega', u'resource_uri': u'api/v1/pokemon/10045/'},
#     {u'name': u'aerodactyl-mega', u'resource_uri': u'api/v1/pokemon/10042/'},
#     {u'name': u'mewtwo-mega-x', u'resource_uri': u'api/v1/pokemon/10043/'},
#     {u'name': u'mewtwo-mega-y', u'resource_uri': u'api/v1/pokemon/10044/'},
#     {u'name': u'scizor-mega', u'resource_uri': u'api/v1/pokemon/10046/'},
#     {u'name': u'medicham-mega', u'resource_uri': u'api/v1/pokemon/10054/'},
#     {u'name': u'heracross-mega', u'resource_uri': u'api/v1/pokemon/10047/'},
#     {u'name': u'houndoom-mega', u'resource_uri': u'api/v1/pokemon/10048/'},
#     {u'name': u'tyranitar-mega', u'resource_uri': u'api/v1/pokemon/10049/'},
#     {u'name': u'blaziken-mega', u'resource_uri': u'api/v1/pokemon/10050/'},
#     {u'name': u'gardevoir-mega', u'resource_uri': u'api/v1/pokemon/10051/'},
#     {u'name': u'mawile-mega', u'resource_uri': u'api/v1/pokemon/10052/'},
#     {u'name': u'aggron-mega', u'resource_uri': u'api/v1/pokemon/10053/'},
#     {u'name': u'manectric-mega', u'resource_uri': u'api/v1/pokemon/10055/'},
#     {u'name': u'banette-mega', u'resource_uri': u'api/v1/pokemon/10056/'},
#     {u'name': u'absol-mega', u'resource_uri': u'api/v1/pokemon/10057/'},
#     {u'name': u'garchomp-mega', u'resource_uri': u'api/v1/pokemon/10058/'},
#     {u'name': u'lucario-mega', u'resource_uri': u'api/v1/pokemon/10059/'},
#     {u'name': u'clefairy', u'resource_uri': u'api/v1/pokemon/35/'},
#     {u'name': u'abomasnow-mega', u'resource_uri': u'api/v1/pokemon/10060/'},
#     {u'name': u'bulbasaur', u'resource_uri': u'api/v1/pokemon/1/'},
#     {u'name': u'charizard', u'resource_uri': u'api/v1/pokemon/6/'},
#     {u'name': u'omastar', u'resource_uri': u'api/v1/pokemon/139/'},
#     {u'name': u'seaking', u'resource_uri': u'api/v1/pokemon/119/'},
#     {u'name': u'flaaffy', u'resource_uri': u'api/v1/pokemon/180/'},
#     {u'name': u'shedinja', u'resource_uri': u'api/v1/pokemon/292/'},
#     {u'name': u'tropius', u'resource_uri': u'api/v1/pokemon/357/'},
#     {u'name': u'combee', u'resource_uri': u'api/v1/pokemon/415/'},
#     {u'name': u'shellos', u'resource_uri': u'api/v1/pokemon/422/'},
#     {u'name': u'skorupi', u'resource_uri': u'api/v1/pokemon/451/'},
#     {u'name': u'heatran', u'resource_uri': u'api/v1/pokemon/485/'},
#     {u'name': u'palkia', u'resource_uri': u'api/v1/pokemon/484/'},
#     {u'name': u'simisear', u'resource_uri': u'api/v1/pokemon/514/'},
#     {u'name': u'tornadus-incarnate', u'resource_uri': u'api/v1/pokemon/641/'},
#     {u'name': u'fraxure', u'resource_uri': u'api/v1/pokemon/611/'},
#     {u'name': u'druddigon', u'resource_uri': u'api/v1/pokemon/621/'},
#     {u'name': u'pangoro', u'resource_uri': u'api/v1/pokemon/675/'},
#     {u'name': u'helioptile', u'resource_uri': u'api/v1/pokemon/694/'},
#     {u'name': u'dragalge', u'resource_uri': u'api/v1/pokemon/691/'},
#     {u'name': u'weepinbell', u'resource_uri': u'api/v1/pokemon/70/'},
#     {u'name': u'sandslash', u'resource_uri': u'api/v1/pokemon/28/'},
#     {u'name': u'samurott', u'resource_uri': u'api/v1/pokemon/503/'},
#     {u'name': u'primeape', u'resource_uri': u'api/v1/pokemon/57/'},
#     {u'name': u'teddiursa', u'resource_uri': u'api/v1/pokemon/216/'},
#     {u'name': u'salamence', u'resource_uri': u'api/v1/pokemon/373/'},
#     {u'name': u'giratina-origin', u'resource_uri': u'api/v1/pokemon/10007/'},
#     {u'name': u'gurdurr', u'resource_uri': u'api/v1/pokemon/533/'},
#     {u'name': u'slowpoke', u'resource_uri': u'api/v1/pokemon/79/'},
#     {u'name': u'hitmontop', u'resource_uri': u'api/v1/pokemon/237/'},
#     {u'name': u'bibarel', u'resource_uri': u'api/v1/pokemon/400/'},
#     {u'name': u'marowak', u'resource_uri': u'api/v1/pokemon/105/'},
#     {u'name': u'castform-snowy', u'resource_uri': u'api/v1/pokemon/10015/'},
#     {u'name': u'zigzagoon', u'resource_uri': u'api/v1/pokemon/263/'},
#     {u'name': u'garbodor', u'resource_uri': u'api/v1/pokemon/569/'},
#     {u'name': u'magikarp', u'resource_uri': u'api/v1/pokemon/129/'},
#     {u'name': u'chatot', u'resource_uri': u'api/v1/pokemon/441/'},
#     {u'name': u'gardevoir', u'resource_uri': u'api/v1/pokemon/282/'},
#     {u'name': u'spinarak', u'resource_uri': u'api/v1/pokemon/167/'},
#     {u'name': u'klinklang', u'resource_uri': u'api/v1/pokemon/601/'},
#     {u'name': u'tangrowth', u'resource_uri': u'api/v1/pokemon/465/'},
#     {u'name': u'meditite', u'resource_uri': u'api/v1/pokemon/307/'},
#     {u'name': u'slowking', u'resource_uri': u'api/v1/pokemon/199/'},
#     {u'name': u'cresselia', u'resource_uri': u'api/v1/pokemon/488/'},
#     {u'name': u'zangoose', u'resource_uri': u'api/v1/pokemon/335/'},
#     {u'name': u'phione', u'resource_uri': u'api/v1/pokemon/489/'},
#     {u'name': u'zweilous', u'resource_uri': u'api/v1/pokemon/634/'},
#     {u'name': u'pyroar', u'resource_uri': u'api/v1/pokemon/668/'}],
#    u'resource_uri': u'/api/v1/pokedex/1/'}]}

# %%
#the api can be used to call anything from the pokemon, to types, to abilities, to moves and so on
#you can get information on a certain pokemon through the 'resource_uri', which is how the api organizes it's information for each pokemon
#by adding /resource_uri/ to the end of 'http://pokeapi.co/api/v1/pokemon'

#FOR EXAMPLE, i want to see information on pokemon number 25
url = 'http://pokeapi.co/api/v1/pokemon/25'
resp = requests.get(url)
data = json.loads(resp.text)
data
# Out:
# {u'abilities': [{u'name': u'static', u'resource_uri': u'/api/v1/ability/9/'},
#   {u'name': u'lightningrod', u'resource_uri': u'/api/v1/ability/31/'}],
#  u'attack': 55,
#  u'catch_rate': 0,
#  u'created': u'2013-11-03T15:05:41.317235',
#  u'defense': 40,
#  u'descriptions': [{u'name': u'pikachu_gen_1',
#    u'resource_uri': u'/api/v1/description/382/'},
#   {u'name': u'pikachu_gen_1', u'resource_uri': u'/api/v1/description/383/'},
#   {u'name': u'pikachu_gen_2', u'resource_uri': u'/api/v1/description/384/'},
#   {u'name': u'pikachu_gen_1', u'resource_uri': u'/api/v1/description/379/'},
#   {u'name': u'pikachu_gen_1', u'resource_uri': u'/api/v1/description/380/'},
#   {u'name': u'pikachu_gen_2', u'resource_uri': u'/api/v1/description/385/'},
#   {u'name': u'pikachu_gen_2', u'resource_uri': u'/api/v1/description/386/'},
#   {u'name': u'pikachu_gen_3', u'resource_uri': u'/api/v1/description/387/'},
#   {u'name': u'pikachu_gen_3', u'resource_uri': u'/api/v1/description/388/'},
#   {u'name': u'pikachu_gen_3', u'resource_uri': u'/api/v1/description/389/'},
#   {u'name': u'pikachu_gen_3', u'resource_uri': u'/api/v1/description/390/'},
#   {u'name': u'pikachu_gen_3', u'resource_uri': u'/api/v1/description/391/'},
#   {u'name': u'pikachu_gen_4', u'resource_uri': u'/api/v1/description/392/'},
#   {u'name': u'pikachu_gen_4', u'resource_uri': u'/api/v1/description/393/'},
#   {u'name': u'pikachu_gen_4', u'resource_uri': u'/api/v1/description/394/'},
#   {u'name': u'pikachu_gen_5', u'resource_uri': u'/api/v1/description/395/'},
#   {u'name': u'pikachu_gen_6', u'resource_uri': u'/api/v1/description/396/'},
#   {u'name': u'pikachu_gen_6', u'resource_uri': u'/api/v1/description/397/'},
#   {u'name': u'pikachu_gen_1', u'resource_uri': u'/api/v1/description/381/'}],
#  u'egg_cycles': 0,
#  u'egg_groups': [{u'name': u'Fairy', u'resource_uri': u'/api/v1/egg/6/'},
#   {u'name': u'Ground', u'resource_uri': u'/api/v1/egg/5/'}],
#  u'ev_yield': u'',
#  u'evolutions': [{u'method': u'stone',
#    u'resource_uri': u'/api/v1/pokemon/26/',
#    u'to': u'Raichu'}],
#  u'exp': 105,
#  u'growth_rate': u'',
#  u'happiness': 0,
#  u'height': u'4',
#  u'hp': 35,
#  u'male_female_ratio': u'',
#  u'modified': u'2013-11-23T13:13:24.383925',
#  u'moves': [{u'learn_type': u'tutor',
#    u'name': u'Covet',
#    u'resource_uri': u'/api/v1/move/343/'},
#   {u'learn_type': u'machine',
#    u'name': u'Wild-charge',
#    u'resource_uri': u'/api/v1/move/528/'},
#   {u'learn_type': u'machine',
#    u'name': u'Volt-switch',
#    u'resource_uri': u'/api/v1/move/521/'},
#   {u'learn_type': u'machine',
#    u'name': u'Echoed-voice',
#    u'resource_uri': u'/api/v1/move/497/'},
#   {u'learn_type': u'machine',
#    u'name': u'Round',
#    u'resource_uri': u'/api/v1/move/496/'},
#   {u'learn_type': u'level up',
#    u'level': 18,
#    u'name': u'Electro-ball',
#    u'resource_uri': u'/api/v1/move/486/'},
#   {u'learn_type': u'tutor',
#    u'name': u'Magnet-rise',
#    u'resource_uri': u'/api/v1/move/393/'},
#   {u'learn_type': u'tutor',
#    u'name': u'Signal-beam',
#    u'resource_uri': u'/api/v1/move/324/'},
#   {u'learn_type': u'tutor',
#    u'name': u'Knock-off',
#    u'resource_uri': u'/api/v1/move/282/'},
#   {u'learn_type': u'tutor',
#    u'name': u'Helping-hand',
#    u'resource_uri': u'/api/v1/move/270/'},
#   {u'learn_type': u'machine',
#    u'name': u'Charge-beam',
#    u'resource_uri': u'/api/v1/move/451/'},
#   {u'learn_type': u'machine',
#    u'name': u'Grass-knot',
#    u'resource_uri': u'/api/v1/move/447/'},
#   {u'learn_type': u'machine',
#    u'name': u'Captivate',
#    u'resource_uri': u'/api/v1/move/445/'},
#   {u'learn_type': u'level up',
#    u'level': 37,
#    u'name': u'Discharge',
#    u'resource_uri': u'/api/v1/move/435/'},
#   {u'learn_type': u'machine',
#    u'name': u'Fling',
#    u'resource_uri': u'/api/v1/move/374/'},
#   {u'learn_type': u'level up',
#    u'level': 29,
#    u'name': u'Feint',
#    u'resource_uri': u'/api/v1/move/364/'},
#   {u'learn_type': u'machine',
#    u'name': u'Natural-gift',
#    u'resource_uri': u'/api/v1/move/363/'},
#   {u'learn_type': u'tutor',
#    u'name': u'Counter',
#    u'resource_uri': u'/api/v1/move/68/'},
#   {u'learn_type': u'machine',
#    u'name': u'Shock-wave',
#    u'resource_uri': u'/api/v1/move/351/'},
#   {u'learn_type': u'machine',
#    u'name': u'Secret-power',
#    u'resource_uri': u'/api/v1/move/290/'},
#   {u'learn_type': u'machine',
#    u'name': u'Brick-break',
#    u'resource_uri': u'/api/v1/move/280/'},
#   {u'learn_type': u'machine',
#    u'name': u'Focus-punch',
#    u'resource_uri': u'/api/v1/move/264/'},
#   {u'learn_type': u'machine',
#    u'name': u'Facade',
#    u'resource_uri': u'/api/v1/move/263/'},
#   {u'learn_type': u'machine',
#    u'name': u'Rock-smash',
#    u'resource_uri': u'/api/v1/move/249/'},
#   {u'learn_type': u'machine',
#    u'name': u'Dig',
#    u'resource_uri': u'/api/v1/move/91/'},
#   {u'learn_type': u'machine',
#    u'name': u'Rain-dance',
#    u'resource_uri': u'/api/v1/move/240/'},
#   {u'learn_type': u'machine',
#    u'name': u'Hidden-power',
#    u'resource_uri': u'/api/v1/move/237/'},
#   {u'learn_type': u'machine',
#    u'name': u'Iron-tail',
#    u'resource_uri': u'/api/v1/move/231/'},
#   {u'learn_type': u'machine',
#    u'name': u'Dynamicpunch',
#    u'resource_uri': u'/api/v1/move/223/'},
#   {u'learn_type': u'machine',
#    u'name': u'Frustration',
#    u'resource_uri': u'/api/v1/move/218/'},
#   {u'learn_type': u'machine',
#    u'name': u'Return',
#    u'resource_uri': u'/api/v1/move/216/'},
#   {u'learn_type': u'machine',
#    u'name': u'Sleep-talk',
#    u'resource_uri': u'/api/v1/move/214/'},
#   {u'learn_type': u'machine',
#    u'name': u'Attract',
#    u'resource_uri': u'/api/v1/move/213/'},
#   {u'learn_type': u'machine',
#    u'name': u'Swagger',
#    u'resource_uri': u'/api/v1/move/207/'},
#   {u'learn_type': u'machine',
#    u'name': u'Rollout',
#    u'resource_uri': u'/api/v1/move/205/'},
#   {u'learn_type': u'machine',
#    u'name': u'Endure',
#    u'resource_uri': u'/api/v1/move/203/'},
#   {u'learn_type': u'machine',
#    u'name': u'Detect',
#    u'resource_uri': u'/api/v1/move/197/'},
#   {u'learn_type': u'machine',
#    u'name': u'Zap-cannon',
#    u'resource_uri': u'/api/v1/move/192/'},
#   {u'learn_type': u'machine',
#    u'name': u'Mud-slap',
#    u'resource_uri': u'/api/v1/move/189/'},
#   {u'learn_type': u'machine',
#    u'name': u'Protect',
#    u'resource_uri': u'/api/v1/move/182/'},
#   {u'learn_type': u'machine',
#    u'name': u'Curse',
#    u'resource_uri': u'/api/v1/move/174/'},
#   {u'learn_type': u'machine',
#    u'name': u'Snore',
#    u'resource_uri': u'/api/v1/move/173/'},
#   {u'learn_type': u'machine',
#    u'name': u'Defense-curl',
#    u'resource_uri': u'/api/v1/move/111/'},
#   {u'learn_type': u'machine',
#    u'name': u'Strength',
#    u'resource_uri': u'/api/v1/move/70/'},
#   {u'learn_type': u'machine',
#    u'name': u'Headbutt',
#    u'resource_uri': u'/api/v1/move/29/'},
#   {u'learn_type': u'machine',
#    u'name': u'Thunderpunch',
#    u'resource_uri': u'/api/v1/move/9/'},
#   {u'learn_type': u'level up',
#    u'level': 50,
#    u'name': u'Light-screen',
#    u'resource_uri': u'/api/v1/move/113/'},
#   {u'learn_type': u'level up',
#    u'level': 6,
#    u'name': u'Tail-whip',
#    u'resource_uri': u'/api/v1/move/39/'},
#   {u'learn_type': u'level up',
#    u'level': 20,
#    u'name': u'Slam',
#    u'resource_uri': u'/api/v1/move/21/'},
#   {u'learn_type': u'machine',
#    u'name': u'Substitute',
#    u'resource_uri': u'/api/v1/move/164/'},
#   {u'learn_type': u'machine',
#    u'name': u'Rest',
#    u'resource_uri': u'/api/v1/move/156/'},
#   {u'learn_type': u'machine',
#    u'name': u'Flash',
#    u'resource_uri': u'/api/v1/move/148/'},
#   {u'learn_type': u'machine',
#    u'name': u'Skull-bash',
#    u'resource_uri': u'/api/v1/move/130/'},
#   {u'learn_type': u'level up',
#    u'level': 26,
#    u'name': u'Swift',
#    u'resource_uri': u'/api/v1/move/129/'},
#   {u'learn_type': u'machine',
#    u'name': u'Bide',
#    u'resource_uri': u'/api/v1/move/117/'},
#   {u'learn_type': u'machine',
#    u'name': u'Reflect',
#    u'resource_uri': u'/api/v1/move/115/'},
#   {u'learn_type': u'machine',
#    u'name': u'Double-team',
#    u'resource_uri': u'/api/v1/move/104/'},
#   {u'learn_type': u'machine',
#    u'name': u'Mimic',
#    u'resource_uri': u'/api/v1/move/102/'},
#   {u'learn_type': u'machine',
#    u'name': u'Rage',
#    u'resource_uri': u'/api/v1/move/99/'},
#   {u'learn_type': u'level up',
#    u'level': 16,
#    u'name': u'Quick-attack',
#    u'resource_uri': u'/api/v1/move/98/'},
#   {u'learn_type': u'level up',
#    u'level': 33,
#    u'name': u'Agility',
#    u'resource_uri': u'/api/v1/move/97/'},
#   {u'learn_type': u'machine',
#    u'name': u'Toxic',
#    u'resource_uri': u'/api/v1/move/92/'},
#   {u'learn_type': u'level up',
#    u'level': 43,
#    u'name': u'Thunder',
#    u'resource_uri': u'/api/v1/move/87/'},
#   {u'learn_type': u'level up',
#    u'level': 9,
#    u'name': u'Thunder-wave',
#    u'resource_uri': u'/api/v1/move/86/'},
#   {u'learn_type': u'machine',
#    u'name': u'Thunderbolt',
#    u'resource_uri': u'/api/v1/move/85/'},
#   {u'learn_type': u'level up',
#    u'level': 1,
#    u'name': u'Thundershock',
#    u'resource_uri': u'/api/v1/move/84/'},
#   {u'learn_type': u'machine',
#    u'name': u'Seismic-toss',
#    u'resource_uri': u'/api/v1/move/69/'},
#   {u'learn_type': u'machine',
#    u'name': u'Submission',
#    u'resource_uri': u'/api/v1/move/66/'},
#   {u'learn_type': u'other',
#    u'name': u'Surf',
#    u'resource_uri': u'/api/v1/move/57/'},
#   {u'learn_type': u'level up',
#    u'level': 1,
#    u'name': u'Growl',
#    u'resource_uri': u'/api/v1/move/45/'},
#   {u'learn_type': u'machine',
#    u'name': u'Double-edge',
#    u'resource_uri': u'/api/v1/move/38/'},
#   {u'learn_type': u'machine',
#    u'name': u'Take-down',
#    u'resource_uri': u'/api/v1/move/36/'},
#   {u'learn_type': u'machine',
#    u'name': u'Body-slam',
#    u'resource_uri': u'/api/v1/move/34/'},
#   {u'learn_type': u'machine',
#    u'name': u'Mega-kick',
#    u'resource_uri': u'/api/v1/move/25/'},
#   {u'learn_type': u'machine',
#    u'name': u'Pay-day',
#    u'resource_uri': u'/api/v1/move/6/'},
#   {u'learn_type': u'machine',
#    u'name': u'Mega-punch',
#    u'resource_uri': u'/api/v1/move/5/'}],
#  u'name': u'Pikachu',
#  u'national_id': 25,
#  u'pkdx_id': 25,
#  u'resource_uri': u'/api/v1/pokemon/25/',
#  u'sp_atk': 50,
#  u'sp_def': 50,
#  u'species': u'',
#  u'speed': 90,
#  u'sprites': [{u'name': u'pikachu', u'resource_uri': u'/api/v1/sprite/26/'}],
#  u'total': 0,
#  u'types': [{u'name': u'electric', u'resource_uri': u'/api/v1/type/13/'}],
#  u'weight': u'60'}

# %% [markdown]
# #### After seeing that all the data is stored in the resource uri, we tried to put all the data within each api call into one dictionary. We tried doing this by using request.get for each url and displaying the data, but there is too much data (over 1000 pokemon), and doing so would only give us certain types of information about the pokemon.
# #### The code below demonstrates our effort to do so.

# %%
url = 'http://pokeapi.co/api/v1/pokedex'
resp = requests.get(url)
data = json.loads(resp.text)
data

pokemons = data["objects"][0]["pokemon"]
for p in pokemons:
    url = 'http://pokeapi.co/' + p["resource_uri"] #we add the 'resource_uri' to the end of the api call url
    resp = requests.get(url)
    data = json.loads(resp.text)
    data #we print the data from the url
    #this will take awhile to run because there is so much data, but it doesn't display because there is too much info

# %% [markdown]
# #### So instead, we looked into the raw data that was stored on the api's github site: https://github.com/phalt/pokeapi/tree/master/data/v2/csv. All of their data for the api is stored as raw csv files, so we just looked for which tables we could connect and would give us interesting information about pokemon.
# #### We decided to scrape the raw csv files (url's) and download and store them in iPython. We created a function that uses request.get to scrape the url and create a new file and save the data to the new file. We use the function for the six tables we wanted to use.

# %%
def create_data_file(url, x):
    data = requests.get(url)
    data_text = data.text
    file_name = x + ".csv"
    file_name = open(file_name, "w")
    file_name.write(data_text)
    file_name.close()

# %%
#Pokemon
create_data_file('https://raw.githubusercontent.com/phalt/pokeapi/master/data/v2/csv/pokemon.csv', "Pokemon")

# %%
#Pokemon Species
create_data_file('https://raw.githubusercontent.com/phalt/pokeapi/master/data/v2/csv/pokemon_species.csv', "pokemon_species")

# %%
#Moves
create_data_file('https://raw.githubusercontent.com/phalt/pokeapi/master/data/v2/csv/moves.csv', "moves")

# %%
#Types (with type names)
create_data_file('https://raw.githubusercontent.com/phalt/pokeapi/master/data/v2/csv/types.csv', "types")

# %%
#Pokemon Types (includes pokemon id and type id)
create_data_file('https://raw.githubusercontent.com/phalt/pokeapi/master/data/v2/csv/pokemon_types.csv', "pokemon_types")

# %%
#Habitats
create_data_file('https://raw.githubusercontent.com/phalt/pokeapi/master/data/v2/csv/pokemon_habitats.csv', "pokemon_habitats")

# %% [markdown]
# # Part 2: Inserting Data into MySQL

# %%
import MySQLdb as mdb 
import sys

#we connect to our database
con = mdb.connect(host = '52.22.76.139',
                  user = 'root', 
                  passwd = 'dwdstudent2015', 
                  charset='utf8', 
                  use_unicode=True);

# %%
# Query to create a database
db_name = 'Pokemon'
create_db_query = "CREATE DATABASE IF NOT EXISTS {0} DEFAULT CHARACTER SET 'utf8'".format(db_name)

# Create a database
cursor = con.cursor()
cursor.execute(create_db_query)
cursor.close()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:7: Warning: Can't create database 'Pokemon'; database exists

# %% [markdown]
# #### We noticed that the first rows of the downloaded files are strings that are the names of the columns, but we cannot insert the data with the first row titles because their data types are different from the rest of the file, so we went and individually deleted the first row of each csv file we downloaded. Some csv files also had missing data, which would also cause an error when inserting the data, so for any files with missing data, we filled them in manually and then reuploaded the csv files (that's why some tables use different file names then the one we created above.

# %%
#create 'pokemon_species' table in 'Pokemon' database
cursor = con.cursor()
db_name = 'Pokemon'
table_name = 'pokemon_species'
create_table_query = '''CREATE TABLE IF NOT EXISTS {0}.{1} 
                                (id int, 
                                Name varchar(100), 
                                generation_id int,
                                evolves_from_species_id varchar(100),
                                evolution_chain_id int,
                                color_id int,
                                shape_id int,
                                habitat_id int,
                                gender_rate int,
                                capture_rate int,
                                base_happiness int,
                                is_baby int,
                                hatch_counter int,
                                has_gender_differences int,
                                growth_rate_id int,
                                forms_switchable int,
                                order_id int,
                                PRIMARY KEY(id)
                                )'''.format(db_name, table_name)
cursor.execute(create_table_query)
cursor.close()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:25: Warning: Table 'pokemon_species' already exists

# %%
#Insert data from 'pokemon_species2.csv' file into 'pokemon_species' table in SQL

query_template = '''INSERT INTO Pokemon.pokemon_species(id, 
                                Name, 
                                generation_id,
                                evolves_from_species_id,
                                evolution_chain_id,
                                color_id,
                                shape_id,
                                habitat_id,
                                gender_rate,
                                capture_rate,
                                base_happiness,
                                is_baby,
                                hatch_counter,
                                has_gender_differences,
                                growth_rate_id,
                                forms_switchable,
                                order_id) VALUES (%d, '%s', %d, '%s', %d, %d, %d, %d, %d,
                                # %d, %d, %d, %d, %d, %d, %d, %d)'''

cursor = con.cursor()

import csv

csv_data = csv.reader(file('pokemon_species2.csv'))
for row in csv_data:
    id = int(row[0])
    Name = row[1]
    generation_id = int(row[2])
    evolves_from_species_id = row[3]
    evolution_chain_id = int(row[4])
    color_id = int(row[5])
    shape_id = int(row[6])
    habitat_id = int(row[7])
    gender_rate = int(row[8])
    capture_rate = int(row[9])
    base_happiness = int(row[10])
    is_baby = int(row[11])
    hatch_counter = int(row[12])
    has_gender_differences = int(row[13])
    growth_rate_id = int(row[14])
    forms_switchable = int(row[15])
    order_id = int(row[16])
    query_parameters = (id, Name, generation_id, evolves_from_species_id, evolution_chain_id,
                        color_id, shape_id, habitat_id, gender_rate, capture_rate, base_happiness,
                        is_baby, hatch_counter, has_gender_differences, growth_rate_id, forms_switchable,
                        order_id)
    full_query = query_template % query_parameters
    cursor.execute(full_query)

    con.commit()

cursor.close()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-20-fbf03f682d2e> in <module>()
#      52                         order_id)
#      53     full_query = query_template % query_parameters
# ---> 54     cursor.execute(full_query)
#      55
#      56     con.commit()
#
# /usr/local/lib/python2.7/dist-packages/MySQLdb/cursors.pyc in execute(self, query, args)
#     203             del tb
#     204             self.messages.append((exc, value))
# --> 205             self.errorhandler(self, exc, value)
#     206         self._executed = query
#     207         if not self._defer_warnings: self._warning_check()
#
# /usr/local/lib/python2.7/dist-packages/MySQLdb/connections.pyc in defaulterrorhandler(***failed resolving arguments***)
#      34     del cursor
#      35     del connection
# ---> 36     raise errorclass, errorvalue
#      37
#      38 re_numeric_part = re.compile(r"^(\d+)")
#
# IntegrityError: (1062, "Duplicate entry '1' for key 'PRIMARY'")

# %%
#create 'moves' table in 'Pokemon' database
cursor = con.cursor()
db_name = 'Pokemon'
table_name = 'moves'
create_table_query = '''CREATE TABLE IF NOT EXISTS {0}.{1} 
                                (id int, 
                                moves_name varchar(100), 
                                generation_id int,
                                type_id int,
                                power int,
                                contest_type_id int,
                                contest_effect_id int,
                                PRIMARY KEY(id)
                                )'''.format(db_name, table_name)
cursor.execute(create_table_query)
cursor.close()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:15: Warning: Table 'moves' already exists

# %%
#Insert data from 'moves2.csv' into 'moves' table in sql
query_template = '''INSERT INTO Pokemon.moves(id, 
                                moves_name, 
                                generation_id,
                                type_id,
                                power,
                                contest_type_id,
                                contest_effect_id) VALUES (%d, '%s', %d, %d, %d, %d, %d)'''

cursor = con.cursor()

import csv

csv_data = csv.reader(file('moves2.csv')) 

for row in csv_data:
    id = int(row[0])
    moves_name = row[1]
    generation_id = int(row[2])
    type_id = int(row[3])
    power = int(row[4])
    contest_type_id = int(row[12])
    contest_effect_id= int(row[13])
    query_parameters = (id, moves_name, generation_id, type_id, power, contest_type_id, contest_effect_id)
    full_query = query_template % query_parameters
    cursor.execute(full_query)

    con.commit()

cursor.close()

# %%
#create 'types_name' table in 'Pokemon' database
cursor = con.cursor()
db_name = 'Pokemon'
table_name = 'types_name'
create_table_query = '''CREATE TABLE IF NOT EXISTS {0}.{1} 
                                (id int, 
                                type_name varchar(100), 
                                generation_id int,
                                damage_class_id int,
                                PRIMARY KEY(id)
                                )'''.format(db_name, table_name)
cursor.execute(create_table_query)
cursor.close()

# %%
#Inserting data into 'types_name' table from 'types.csv'
query_template = '''INSERT INTO Pokemon.types_name(id, 
                                        type_name, 
                                        generation_id,
                                        damage_class_id) VALUES (%d, '%s', %d, %d)'''

cursor = con.cursor()
import csv
csv_data = csv.reader(file('types.csv'))
for row in csv_data:
    id = int(row[0])
    type_name = row[1]
    generation_id = int(row[2])
    damage_class_id = int(row[3])
    query_parameters = (id, type_name, generation_id, damage_class_id)
    full_query = query_template % query_parameters
    cursor.execute(full_query)
    con.commit()

cursor.close()

# %%
#create 'pokemon' table in 'Pokemon' database
cursor = con.cursor()
db_name = 'Pokemon'
table_name = 'pokemon'
create_pokemon_table_query = '''CREATE TABLE IF NOT EXISTS {0}.{1} 
                                (id int, 
                                name varchar(100), 
                                species_id int,
                                height int,
                                weight int,
                                base_experience int,
                                order_id int,
                                default_id int,
                                pokemon_species_id int,
                                FOREIGN KEY (pokemon_species_id) REFERENCES pokemon_species(id),
                                PRIMARY KEY(id)
                                )'''.format(db_name, table_name)
cursor.execute(create_pokemon_table_query)
cursor.close()

# %%
#inserting data from 'Pokemon.csv' into 'pokemon' table in sql
query_template = '''INSERT INTO Pokemon.pokemon(id, 
                                        Name, 
                                        species_id,
                                        height,
                                        weight,
                                        base_experience,
                                        order_id,
                                        default_id) VALUES (%d, '%s', %d, %d, %d, %d, %d, %d)'''

cursor = con.cursor()

import csv

csv_data = csv.reader(file('Pokemon.csv'))

for row in csv_data:
    id = int(row[0])
    Name = row[1]
    species_id = int(row[2])
    height = int(row[3])
    weight = int(row[4])
    base_experience = int(row[5])
    order_id = int(row[6])
    default_id = int(row[7])
    query_parameters = (id, Name, species_id, height, weight, base_experience, order_id, default_id)
    full_query = query_template % query_parameters
    cursor.execute(full_query)

    con.commit()

cursor.close()

# %%
#create 'pokemon_habitats' table in 'Pokemon' database
cursor = con.cursor()
db_name = 'Pokemon'
table_name = 'pokemon_habitats'
create_table_query = '''CREATE TABLE IF NOT EXISTS {0}.{1} 
                                (id int, 
                                habitat_name text,
                                pokemon_id,
                                FOREIGN KEY (pokemon_id) REFERENCES pokemon(id),
                                PRIMARY KEY(id)
                                )'''.format(db_name, table_name)
cursor.execute(create_table_query)
cursor.close()

# %%
#Insert data from 'pokemon_habitats.csv' into 'pokemon_habitats' table in sql
query_template = '''INSERT INTO Pokemon.pokemon_habitats(id, 
                                        habitat_name) VALUES (%d, '%s')'''

cursor = con.cursor()

import csv

csv_data = csv.reader(file('pokemon_habitats.csv'))

for row in csv_data:
    id = int(row[0])
    habitat_name = row[1]
    query_parameters = (id, habitat_name)
    full_query = query_template % query_parameters
    cursor.execute(full_query)

    con.commit()

cursor.close()

# %%
#create table for 'pokemon_types' table
#there is no primary key for this table, because it is organized by pokemon id, but a pokemon can have more than 1 type

cursor = con.cursor()
db_name = 'Pokemon'
table_name = 'pokemon_types'
create_table_query = '''CREATE TABLE IF NOT EXISTS {0}.{1} 
                                (pokemon_id int, 
                                type_id int,
                                slot int,
                                types_name_id int,
                                FOREIGN KEY (types_name_id) REFERENCES types_name(id) 
                                )'''.format(db_name, table_name)
cursor.execute(create_table_query)
cursor.close()

# %%
#insert data from 'pokemon_types.csv' into 'pokemon_types' table in sql
query_template = '''INSERT INTO Pokemon.pokemon_types(pokemon_id, 
                                        type_id, 
                                        slot) VALUES (%d, %d, %d)'''

cursor = con.cursor()
import csv
csv_data = csv.reader(file('pokemon_types.csv'))
for row in csv_data:
    pokemon_id = int(row[0])
    type_id = int(row[1])
    slot = int(row[2])
    query_parameters = (pokemon_id, type_id, slot)
    full_query = query_template % query_parameters
    cursor.execute(full_query)
    con.commit()

cursor.close()

# %% [markdown]
# # PART 3: SQL QUERIES

# %%
#Connect to SQL
# %load_ext sql

# %sql mysql://root:dwdstudent2015@52.22.76.139:3306/Pokemon
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /usr/local/lib/python2.7/dist-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# u'Connected: root@Pokemon'

# %%
# %%sql
# #query 1: List the number of pokemon within each type in descending order
#
# SELECT TN.type_name, COUNT(TN.type_name) AS num_of_this_type
# FROM types_name TN
#     INNER JOIN pokemon_types PT ON PT.type_id = TN.id
#     INNER JOIN pokemon P ON P.id = PT.pokemon_id
# GROUP BY TN.type_name
# ORDER BY COUNT(TN.type_name) DESC;
# Out:
# 18 rows affected.
# [('water', 118L),
#  ('normal', 97L),
#  ('flying', 90L),
#  ('grass', 84L),
#  ('psychic', 74L),
#  ('bug', 66L),
#  ('ground', 60L),
#  ('poison', 59L),
#  ('fire', 56L),
#  ('rock', 55L),
#  ('dark', 44L),
#  ('fighting', 44L),
#  ('electric', 42L),
#  ('steel', 41L),
#  ('dragon', 38L),
#  ('ghost', 35L),
#  ('fairy', 35L),
#  ('ice', 33L)]

# %%
# %%sql
# #query 2: Which types of moves are most useful in pokemon contests?
#
# #create view first
# CREATE VIEW contest_moves AS
# 	SELECT M.type_id, TN.type_name, M.moves_name, M.contest_type_id, M.contest_effect_id
# 	FROM moves M
# 		INNER JOIN types_name TN ON TN.id = M.type_id
# 	WHERE contest_effect_id >= 30
# 	ORDER BY contest_effect_id DESC;
#
# #then select the table
# SELECT type_name, COUNT(type_id) AS num_moves_per_type, contest_type_id,
# contest_effect_id
# FROM contest_moves
# GROUP BY type_name, contest_type_id, contest_effect_id
# ORDER BY COUNT(type_id) DESC;
# Out:
# (_mysql_exceptions.OperationalError) (1050, "Table 'contest_moves' already exists") [SQL: u'#query 2: Which types of moves are most useful in pokemon contests?\n\n#create view first\nCREATE VIEW contest_moves AS\n\tSELECT M.type_id, TN.type_name, M.moves_name, M.contest_type_id, M.contest_effect_id\n\tFROM moves M \n\t\tINNER JOIN types_name TN ON TN.id = M.type_id\n\tWHERE contest_effect_id >= 30\n\tORDER BY contest_effect_id DESC;']

# %%
# %%sql
# #query 3: What moves can grass-type pokemon have?
#
# #find what type_id grass is
# SELECT TN.type_name, TN.id
# FROM types_name TN
# WHERE TN.type_name = 'grass';
#
# #then find the moves with that type_id
# SELECT M.moves_name, M.type_id
# FROM pokemon_types PT
#     INNER JOIN moves M ON PT.type_id = M.type_id
#     INNER JOIN pokemon P ON P.id = PT.pokemon_id
# WHERE M.type_id = 12
# GROUP BY moves_name;
# Out:
# 1 rows affected.
# 37 rows affected.
# [('absorb', 12L),
#  ('aromatherapy', 12L),
#  ('bullet-seed', 12L),
#  ('cotton-guard', 12L),
#  ('cotton-spore', 12L),
#  ('energy-ball', 12L),
#  ('forests-curse', 12L),
#  ('frenzy-plant', 12L),
#  ('giga-drain', 12L),
#  ('grass-knot', 12L),
#  ('grass-pledge', 12L),
#  ('grass-whistle', 12L),
#  ('grassy-terrain', 12L),
#  ('horn-leech', 12L),
#  ('ingrain', 12L),
#  ('leaf-blade', 12L),
#  ('leaf-storm', 12L),
#  ('leaf-tornado', 12L),
#  ('leech-seed', 12L),
#  ('magical-leaf', 12L),
#  ('mega-drain', 12L),
#  ('needle-arm', 12L),
#  ('petal-blizzard', 12L),
#  ('petal-dance', 12L),
#  ('power-whip', 12L),
#  ('razor-leaf', 12L),
#  ('seed-bomb', 12L),
#  ('seed-flare', 12L),
#  ('sleep-powder', 12L),
#  ('solar-beam', 12L),
#  ('spiky-shield', 12L),
#  ('spore', 12L),
#  ('stun-spore', 12L),
#  ('synthesis', 12L),
#  ('vine-whip', 12L),
#  ('wood-hammer', 12L),
#  ('worry-seed', 12L)]

# %%
# %%sql
# #query 4: Which type of pokemon has the highest average power of moves?
#
# SELECT TN.type_name, AVG(M.power) as average_power
# FROM types_name TN
# 	INNER JOIN pokemon_species PS on TN.generation_id = PS.generation_id
#     INNER JOIN moves M on M.type_id = TN.id
# GROUP BY TN.type_name
# ORDER BY average_power DESC;
# Out:
# 19 rows affected.
# [('fire', Decimal('83.3333')),
#  ('dragon', Decimal('74.2308')),
#  ('water', Decimal('62.3214')),
#  ('flying', Decimal('59.7826')),
#  ('fighting', Decimal('58.5714')),
#  ('rock', Decimal('58.1250')),
#  ('ice', Decimal('57.8571')),
#  ('electric', Decimal('51.4815')),
#  ('grass', Decimal('49.4595')),
#  ('ground', Decimal('47.3810')),
#  ('shadow', Decimal('45.0000')),
#  ('steel', Decimal('43.4211')),
#  ('poison', Decimal('42.6087')),
#  ('bug', Decimal('36.8000')),
#  ('ghost', Decimal('35.8333')),
#  ('fairy', Decimal('31.4706')),
#  ('dark', Decimal('30.3226')),
#  ('normal', Decimal('28.7267')),
#  ('psychic', Decimal('25.8333'))]

# %%
# %%sql
# #query 5: Which generation of pokemon has the highest average weight? Out of that generation, which pokemon weighs the most?
#
# #find which generation had the heaviest pokemon
# SELECT PS.generation_id, AVG(P.weight) AS avg_weight
# FROM pokemon P
# 	INNER JOIN pokemon_species PS ON P.id = PS.id
# GROUP BY generation_id
# ORDER BY avg_weight DESC;
#
# #find which pokemon out of that generation is the heaviest
# SELECT PS.name, MAX(P.weight)
# FROM pokemon P
# 	INNER JOIN pokemon_species PS ON P.id = PS.id
# WHERE generation_id = 4
# GROUP BY PS.name
# ORDER BY MAX(P.weight) DESC
# LIMIT 1;
# Out:
# 6 rows affected.
# 1 rows affected.
# [('giratina', 7500L)]
